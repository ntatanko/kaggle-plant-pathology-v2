# %%
import os

import numpy as np
import pandas as pd

# import warnings
# warnings.filterwarnings("ignore")
from IPython.core.interactiveshell import InteractiveShell

InteractiveShell.ast_node_interactivity = "all"
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# %matplotlib inline
import sklearn
from sklearn import metrics
import tensorflow as tf
import tensorflow_addons as tfa
from PIL import Image
from tensorflow import keras
from tensorflow.keras.applications.resnet import ResNet50
from tensorflow.keras.layers import (
    AveragePooling2D,
    AvgPool2D,
    Conv2D,
    Dense,
    Flatten,
    GlobalAveragePooling2D,
    MaxPooling2D,
)
from tensorflow.keras.layers.experimental import preprocessing
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# from venn import venn

# %%
PATH = "/app/_data/"
IMG_PATH = '/app/_data/train_images/small_bicubic/'
BATCH_SIZE = 64
SEED = 42
IMAGE_SIZE = (224, 224)
NUM_CLASSES = 5
INPUT_SIZE = (224, 224, 3)

# %%
labels = pd.read_csv(PATH+'train_labels.csv',index_col=[0])
sample_submission = pd.read_csv(PATH + "sample_submission.csv")

# %%
sample_submission
# Out:
#                   image   labels
# 0  85f8cb619c66b863.jpg  healthy
# 1  ad8770db05586b59.jpg  healthy
# 2  c7b03e718489f3ca.jpg  healthy

# %%
labels.head()
labels.info()
# Out:
#                   image                           labels
# 0  800113bb65efe69e.jpg                          healthy
# 1  8002cb321f8bfcdf.jpg  scab frog_eye_leaf_spot complex
# 2  80070f7fb5e2ccaa.jpg                             scab
# 3  80077517781fb94f.jpg                             scab
# 4  800cbf0ff87721f8.jpg                          complex
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18532 entries, 0 to 18631
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   image   18532 non-null  object
#  1   labels  18532 non-null  object
# dtypes: object(2)
# memory usage: 434.3+ KB

# %%
labels["labels"].value_counts(normalize=True)
# Out:
# scab                               0.260091
# healthy                            0.249514
# frog_eye_leaf_spot                 0.171541
# rust                               0.096967
# complex                            0.085258
# powdery_mildew                     0.063889
# scab frog_eye_leaf_spot            0.037017
# scab frog_eye_leaf_spot complex    0.010792
# frog_eye_leaf_spot complex         0.008904
# rust frog_eye_leaf_spot            0.006421
# rust complex                       0.004910
# powdery_mildew complex             0.004695
# Name: labels, dtype: float64

# %%
labels = labels.join(labels["labels"].str.get_dummies(sep=" "))

# %%
feature_columns = labels.columns[2:].tolist()
feature_columns = ['complex', 'frog_eye_leaf_spot', 'powdery_mildew', 'rust', 'scab']

# %% [markdown]
# ## resizing and saving images

# %%
# def resize_im(
#     image_name, new_folder_name="666_bicubic", size=(666, 666), resample=Image.BICUBIC
# ):
#     image = Image.open(PATH + "train_images/" + image_name)
#     image = image.resize(size, resample=resample)
#     if not os.path.isdir(PATH + "train_images/" + new_folder_name + "/"):
#         os.mkdir(PATH + "train_images/" + new_folder_name + "/")
#     image.save(PATH + "train_images/" + new_folder_name + "/" + image_name)
# labels['image'].apply(resize_im)

# %% [markdown]
# ## weights

# %%
# labels["multi_label"] = labels["labels"].astype("category").cat.codes
# dict_weights = (
#     1
#     / labels["multi_label"].value_counts()
#     / np.sum(1 / labels["multi_label"].value_counts())
# ).to_dict()
# def weight_fill(x):
#    return dict_weights[x]
# labels['weights'] = labels["multi_label"].apply(weight_fill)

# %% [markdown]
# ## ImageDataGenerator

# %%
train_datagen = ImageDataGenerator(
    validation_split=0.2,
    rescale=1.0 / 255,
    rotation_range=45,
    width_shift_range=0.25,
    height_shift_range=0.25,
    brightness_range=(0.5, 1.5),
    shear_range=45,
    zoom_range=0.25,
    horizontal_flip=True,
    vertical_flip=True,
)
train = train_datagen.flow_from_dataframe(
    dataframe=labels,
    directory=IMG_PATH,
    x_col="image",
    y_col=feature_columns,
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode="raw",
    subset="training",
    seed=SEED,
    interpolation = 'bicubic'
)
# Out:
# Found 14826 validated image filenames.

# %%
valid_datagen = ImageDataGenerator(
    validation_split=0.2,
    rescale=1.0 / 255,
)
valid = valid_datagen.flow_from_dataframe(
    dataframe=labels,
    directory=IMG_PATH,
    x_col="image",
    y_col=feature_columns,
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode="raw",
    subset="validation",
    seed=SEED,
    interpolation = 'bicubic',
    shuffle=False,

)
# Out:
# Found 3706 validated image filenames.

# %%
test_datagen = ImageDataGenerator(rescale=1.0 / 255)
test = test_datagen.flow_from_dataframe(
    dataframe=sample_submission,
    directory=PATH + "test_images/",
    x_col="image",
    y_col=None,
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode=None,
    seed=SEED,
    shuffle=False,
    interpolation = 'bicubic'
)
# Out:
# Found 3 validated image filenames.

# %% [markdown]
# ### plots

# %%
def plot_curves(model, loss=False):
    df = pd.DataFrame(model.history)
    if loss:
        plt.figure(figsize=(12, 6))
        plt.title("loss")
        plt.plot(df.iloc[:, 0], label="loss")
        plt.plot(df.iloc[:, 5], label="val_loss")
        plt.legend()
        plt.show()
    else:
        plt.figure(figsize=(12, 20))
        plt.subplot(4, 1, 1)
        plt.title("accuracy")
        plt.plot(df.iloc[:, 1], label="accuracy")
        plt.plot(df.iloc[:, 6], label="val_accuracy")
        plt.legend()

        plt.subplot(4, 1, 2)
        plt.title("recall")
        plt.plot(df.iloc[:, 2], label="recall")
        plt.plot(df.iloc[:, 7], label="val_recall")
        plt.legend()

        plt.subplot(4, 1, 3)
        plt.title("precision")
        plt.plot(df.iloc[:, 3], label="precision")
        plt.plot(df.iloc[:, 8], label="val_precision")
        plt.legend()

        plt.subplot(4, 1, 4)
        plt.title("f1")
        plt.plot(df.iloc[:, 4], label="f1")
        plt.plot(df.iloc[:, 9], label="val_f1")
        plt.legend()
        plt.show();

# %% [markdown]
# ## model

# %% [markdown]
# ### base_model

# %%
# backbone = ResNet50(input_shape=(224, 224, 3), weights="imagenet", include_top=False)
# model_w = Sequential()
# model_w.add(backbone)
# model_w.add(GlobalAveragePooling2D())
# model_w.add(Dense(units=7, activation="sigmoid"))
# model_w.compile(
#     loss="CategoricalCrossentropy",
#     optimizer=Adam(lr=0.001),
#     metrics=[keras.metrics.CategoricalAccuracy(), keras.metrics.Recall(), keras.metrics.Precision(), tfa.metrics.F1Score(
#                     num_classes=7,
#                     average='macro')]
# )

# %% [markdown]
# ### from keras
# <https://keras.io/guides/preprocessing_layers/#image-preprocessing-layers>

# %%
data_augmentation = keras.Sequential(
    [
#         keras.layers.experimental.preprocessing.Normalization(),
#         keras.layers.experimental.preprocessing.Resizing(224,224),
        keras.layers.experimental.preprocessing.RandomFlip("horizontal_and_vertical"),
        keras.layers.experimental.preprocessing.RandomHeight(0.1),
        keras.layers.experimental.preprocessing.RandomWidth(0.1),
        keras.layers.experimental.preprocessing.RandomRotation(0.15),
        keras.layers.experimental.preprocessing.RandomZoom(0.25, 0.25),
        
    ]
)
#         keras.preprocessing.image.random_shear(45),
#         keras.preprocessing.image.random_rotation(45),
#         keras.preprocessing.image.random_brightness(0.5, 1.5),
#         keras.preprocessing.image.random_zoom(0.75, 1.25),
#         keras.preprocessing.image.random_shift(0.25, 0.25)
# x = keras.preprocessing.image.random_shear(x, 45, row_axis=0, col_axis=1, channel_axis=2),
# x = keras.preprocessing.image.random_rotation(x, 45, row_axis=0, col_axis=1, channel_axis=2),
# x = keras.preprocessing.image.random_brightness(x, (0.5, 1.5)),
# x = keras.preprocessing.image.random_zoom(x, (0.75, 1.25), row_axis=0, col_axis=1, channel_axis=2),
# x = keras.preprocessing.image.random_shift(x, 0.25, 0.25, row_axis=0, col_axis=1, channel_axis=2)

# %%
# def preprocess_data(x, y):
#     x_p = data_augmentation(x)
#     x_p = keras.applications.resnet.preprocess_input(x_p)
#     return (x_p, y)

# %%
# preprocess_data(next(valid)[0])

# %% [markdown]
# ### func style

# %%
inputs = keras.Input(shape=INPUT_SIZE)
# x = data_augmentation(inputs)
# x = keras.applications.resnet.preprocess_input(inputs)
x = keras.applications.ResNet50(weights="imagenet", include_top=False)(inputs)
x = keras.layers.GlobalAveragePooling2D(name="avg_pool")(x)
x = keras.layers.Flatten(name="flatten")(x)
outputs = keras.layers.Dense(NUM_CLASSES, activation="sigmoid")(x)
model = keras.Model(inputs=inputs, outputs=outputs)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94773248/94765736 [==============================] - 7s 0us/step

# %%
def scheduler(epoch, lr):
    if epoch < 50:
        return lr
#     elif 5 <= epoch:
#         return 0.0005
    else:
        return 0.0001

# %%
callbacks=[
        keras.callbacks.EarlyStopping(monitor='val_loss',
            patience=7, restore_best_weights=True, verbose=1),
        keras.callbacks.LearningRateScheduler(schedule = scheduler, verbose=1)
        ]

# %%
model.compile(
    loss="binary_crossentropy",
    optimizer=Adam(lr=0.0005),
    metrics=['acc',
        keras.metrics.Recall(),
        keras.metrics.Precision(),
        tfa.metrics.F1Score(num_classes=NUM_CLASSES, average="micro"),
    ],
)

# %%
model.summary()
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# resnet50 (Functional)        (None, None, None, 2048)  23587712
# _________________________________________________________________
# avg_pool (GlobalAveragePooli (None, 2048)              0
# _________________________________________________________________
# flatten (Flatten)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 5)                 10245
# =================================================================
# Total params: 23,597,957
# Trainable params: 23,544,837
# Non-trainable params: 53,120
# _________________________________________________________________

# %%
history = model.fit(
    train,
    validation_data=valid,
    epochs=50,
    batch_size=BATCH_SIZE,
    verbose=1,
    use_multiprocessing=True,
    callbacks = callbacks
)
# Out:
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 1/50
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 231/232 [============================>.] - ETA: 0s - loss: 0.2360 - acc: 0.5474 - recall: 0.6153 - precision: 0.7672 - f1_score: 0.6274WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 232/232 [==============================] - ETA: 0s - loss: 0.2360 - acc: 0.5476 - recall: 0.6154 - precision: 0.7674 - f1_score: 0.6278WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 232/232 [==============================] - 209s 899ms/step - loss: 0.2360 - acc: 0.5476 - recall: 0.6154 - precision: 0.7674 - f1_score: 0.6278 - val_loss: 3.5164 - val_acc: 0.2979 - val_recall: 0.3958 - val_precision: 0.3338 - val_f1_score: 0.3622
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 2/50
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 231/232 [============================>.] - ETA: 0s - loss: 0.1807 - acc: 0.5971 - recall: 0.7161 - precision: 0.8306 - f1_score: 0.6820WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 232/232 [==============================] - ETA: 0s - loss: 0.1808 - acc: 0.5969 - recall: 0.7161 - precision: 0.8304 - f1_score: 0.6818WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 232/232 [==============================] - 206s 889ms/step - loss: 0.1808 - acc: 0.5969 - recall: 0.7161 - precision: 0.8304 - f1_score: 0.6818 - val_loss: 1.8772 - val_acc: 0.2979 - val_recall: 0.6435 - val_precision: 0.2606 - val_f1_score: 0.3622
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 3/50
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 231/232 [============================>.] - ETA: 0s - loss: 0.1685 - acc: 0.6083 - recall: 0.7368 - precision: 0.8384 - f1_score: 0.6930WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 232/232 [==============================] - ETA: 0s - loss: 0.1688 - acc: 0.6083 - recall: 0.7366 - precision: 0.8382 - f1_score: 0.6929WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 232/232 [==============================] - 208s 897ms/step - loss: 0.1688 - acc: 0.6083 - recall: 0.7366 - precision: 0.8382 - f1_score: 0.6929 - val_loss: 0.5697 - val_acc: 0.1457 - val_recall: 0.1338 - val_precision: 0.1794 - val_f1_score: 0.1745
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 4/50
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 231/232 [============================>.] - ETA: 0s - loss: 0.1587 - acc: 0.6156 - recall: 0.7568 - precision: 0.8497 - f1_score: 0.6999WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 232/232 [==============================] - ETA: 0s - loss: 0.1587 - acc: 0.6155 - recall: 0.7567 - precision: 0.8497 - f1_score: 0.6998WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 232/232 [==============================] - 209s 902ms/step - loss: 0.1587 - acc: 0.6155 - recall: 0.7567 - precision: 0.8497 - f1_score: 0.6998 - val_loss: 0.3691 - val_acc: 0.5235 - val_recall: 0.4173 - val_precision: 0.7091 - val_f1_score: 0.5903
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 5/50
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 231/232 [============================>.] - ETA: 0s - loss: 0.1506 - acc: 0.6219 - recall: 0.7673 - precision: 0.8553 - f1_score: 0.7075WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 232/232 [==============================] - ETA: 0s - loss: 0.1507 - acc: 0.6215 - recall: 0.7674 - precision: 0.8553 - f1_score: 0.7072WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 232/232 [==============================] - 213s 918ms/step - loss: 0.1507 - acc: 0.6215 - recall: 0.7674 - precision: 0.8553 - f1_score: 0.7072 - val_loss: 0.1605 - val_acc: 0.6538 - val_recall: 0.7549 - val_precision: 0.8569 - val_f1_score: 0.7358
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 6/50
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 231/232 [============================>.] - ETA: 0s - loss: 0.1473 - acc: 0.6216 - recall: 0.7724 - precision: 0.8519 - f1_score: 0.7084WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 232/232 [==============================] - ETA: 0s - loss: 0.1476 - acc: 0.6215 - recall: 0.7723 - precision: 0.8517 - f1_score: 0.7083WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 232/232 [==============================] - 212s 916ms/step - loss: 0.1476 - acc: 0.6215 - recall: 0.7723 - precision: 0.8517 - f1_score: 0.7083 - val_loss: 0.1923 - val_acc: 0.6212 - val_recall: 0.7043 - val_precision: 0.8541 - val_f1_score: 0.6945
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 7/50
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 231/232 [============================>.] - ETA: 0s - loss: 0.1458 - acc: 0.6282 - recall: 0.7718 - precision: 0.8553 - f1_score: 0.7113WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 232/232 [==============================] - ETA: 0s - loss: 0.1458 - acc: 0.6280 - recall: 0.7720 - precision: 0.8552 - f1_score: 0.7111WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 232/232 [==============================] - 211s 909ms/step - loss: 0.1458 - acc: 0.6280 - recall: 0.7720 - precision: 0.8552 - f1_score: 0.7111 - val_loss: 0.2719 - val_acc: 0.5812 - val_recall: 0.5882 - val_precision: 0.7892 - val_f1_score: 0.6523
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 8/50
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 231/232 [============================>.] - ETA: 0s - loss: 0.1402 - acc: 0.6305 - recall: 0.7908 - precision: 0.8621 - f1_score: 0.7170WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 232/232 [==============================] - ETA: 0s - loss: 0.1400 - acc: 0.6310 - recall: 0.7911 - precision: 0.8624 - f1_score: 0.7173WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 232/232 [==============================] - 202s 872ms/step - loss: 0.1400 - acc: 0.6310 - recall: 0.7911 - precision: 0.8624 - f1_score: 0.7173 - val_loss: 0.2408 - val_acc: 0.6287 - val_recall: 0.6362 - val_precision: 0.8409 - val_f1_score: 0.7027
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 9/50
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 231/232 [============================>.] - ETA: 0s - loss: 0.1402 - acc: 0.6329 - recall: 0.7871 - precision: 0.8617 - f1_score: 0.7161WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 232/232 [==============================] - ETA: 0s - loss: 0.1400 - acc: 0.6332 - recall: 0.7872 - precision: 0.8621 - f1_score: 0.7162WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 232/232 [==============================] - 209s 903ms/step - loss: 0.1400 - acc: 0.6332 - recall: 0.7872 - precision: 0.8621 - f1_score: 0.7162 - val_loss: 0.2508 - val_acc: 0.5809 - val_recall: 0.5866 - val_precision: 0.7973 - val_f1_score: 0.6576
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 10/50
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 231/232 [============================>.] - ETA: 0s - loss: 0.1378 - acc: 0.6300 - recall: 0.7908 - precision: 0.8615 - f1_score: 0.7175WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 232/232 [==============================] - ETA: 0s - loss: 0.1378 - acc: 0.6301 - recall: 0.7909 - precision: 0.8616 - f1_score: 0.7176WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 232/232 [==============================] - 212s 913ms/step - loss: 0.1378 - acc: 0.6301 - recall: 0.7909 - precision: 0.8616 - f1_score: 0.7176 - val_loss: 0.2239 - val_acc: 0.6233 - val_recall: 0.6480 - val_precision: 0.8759 - val_f1_score: 0.7097
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 11/50
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 231/232 [============================>.] - ETA: 0s - loss: 0.1357 - acc: 0.6324 - recall: 0.7946 - precision: 0.8654 - f1_score: 0.7180WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 232/232 [==============================] - ETA: 0s - loss: 0.1359 - acc: 0.6323 - recall: 0.7943 - precision: 0.8655 - f1_score: 0.7179WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 232/232 [==============================] - 206s 888ms/step - loss: 0.1359 - acc: 0.6323 - recall: 0.7943 - precision: 0.8655 - f1_score: 0.7179 - val_loss: 0.3241 - val_acc: 0.5232 - val_recall: 0.4486 - val_precision: 0.7587 - val_f1_score: 0.5821
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 12/50
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 231/232 [============================>.] - ETA: 0s - loss: 0.1329 - acc: 0.6330 - recall: 0.7950 - precision: 0.8681 - f1_score: 0.7206WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 232/232 [==============================] - ETA: 0s - loss: 0.1328 - acc: 0.6331 - recall: 0.7952 - precision: 0.8682 - f1_score: 0.7208WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# Restoring model weights from the end of the best epoch.
# 232/232 [==============================] - 206s 886ms/step - loss: 0.1328 - acc: 0.6331 - recall: 0.7952 - precision: 0.8682 - f1_score: 0.7208 - val_loss: 0.2962 - val_acc: 0.5059 - val_recall: 0.3894 - val_precision: 0.8457 - val_f1_score: 0.5841
# Epoch 00012: early stopping

# %%
history_res50_5class = pd.DataFrame(history.history)
history_res50_5class.to_csv("history_res50_5class.csv")
model.save("/app/_data/models/res50_5class.h5")

# %%
plot_curves(history)

# %%
plot_curves(history, loss=True)

# %%
def get_prediction(predict_train =False, predict_valid=False, all_img = False):
    if all_img:
        all_img = ImageDataGenerator(rescale=1.0 / 255).flow_from_dataframe(
        dataframe=labels,
        directory=IMG_PATH,
        x_col="image",
        y_col=feature_columns,
        target_size=IMAGE_SIZE,
        batch_size=BATCH_SIZE,
        class_mode="raw",
        seed=SEED,
        interpolation = 'bicubic',
        shuffle=False,
    )
        prediction_all = model.predict(all_img)
        prediction = pd.DataFrame(prediction_all, columns=feature_columns).join(pd.DataFrame(all_img._targets, columns=feature_columns), rsuffix='_true', lsuffix = '_pred')
        prediction.index = all_img.filenames
    elif predict_valid:       
        prediction_valid = model.predict(valid)
        prediction = pd.DataFrame(prediction_valid, columns=feature_columns).join(pd.DataFrame(valid._targets, columns=feature_columns), rsuffix='_true', lsuffix = '_pred')
        prediction.index = valid.filenames
    elif predict_train:
        train = train_datagen.flow_from_dataframe(
            dataframe=labels,
            directory=IMG_PATH,
            x_col="image",
            y_col=feature_columns,
            target_size=IMAGE_SIZE,
            batch_size=BATCH_SIZE,
            class_mode="raw",
            subset="training",
            seed=SEED,
            interpolation = 'bicubic',
            shuffle=False
        )
        prediction_train = model.predict(train)
        prediction = pd.DataFrame(prediction_train, columns=feature_columns).join(pd.DataFrame(train._targets, columns=feature_columns), rsuffix='_true', lsuffix = '_pred')
        prediction.index = train.filenames
    return prediction

# %%
pred_all = get_prediction(all_img=True)
pred_all.to_csv('/app/sandbox/wrong_predictions/prediction_raw_2_5classes.csv')
# Out:
# Found 18532 validated image filenames.

# %% [markdown]
# ## test

# %%
prediction = model.predict(test) > 0.5

# %%
test_sub = pd.DataFrame(prediction, columns=feature_columns)
for name in test_sub.columns.tolist():
    test_sub[name] = test_sub[name].replace({True: name, False: ""})
test_sub["all"] = test_sub.apply(" ".join, axis=1).str.split().str.join(sep=" ")
test_sub.to_csv("app/sandbox/test_sub.csv")

# %%
backbone = ResNet50(input_shape=(224, 224, 3), weights="imagenet", include_top=False)
model = Sequential()
model.add(backbone)
model.add(GlobalAveragePooling2D())
model.add(Dense(units=6, activation="sigmoid"))
model.compile(
    loss='binary_crossentropy',
    optimizer=Adam(lr=0.0001),
    metrics=[
        keras.metrics.CategoricalAccuracy(),
        keras.metrics.Recall(),
        keras.metrics.Precision(),
        tfa.metrics.F1Score(num_classes=6, average="micro"),
    ],
)

# %%
history = model.fit(
    train,
    validation_data=valid,
    epochs=3,
    batch_size=BATCH_SIZE,
    #     steps_per_epoch=64,
    #     validation_steps=16,
    verbose=1,
    use_multiprocessing=True,
)

# %%
model_l = keras.models.load_model('/app/_data/models/base_model')

# %%
a = model_l.predict(valid)

# %%
a[0]
