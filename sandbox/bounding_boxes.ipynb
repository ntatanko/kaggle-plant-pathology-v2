# %%
import os
import json
import numpy as np
import pandas as pd
from IPython.core.interactiveshell import InteractiveShell

InteractiveShell.ast_node_interactivity = "all"
import warnings

warnings.filterwarnings("ignore")

import matplotlib.pyplot as plt

# %matplotlib inline

import sklearn
import tensorflow as tf
import tensorflow_addons as tfa
from PIL import Image

from sklearn.model_selection import (
    StratifiedKFold,
    StratifiedShuffleSplit,
    train_test_split,
)
from tensorflow import keras
from tensorflow.keras.applications.efficientnet import EfficientNetB4, EfficientNetB7, EfficientNetB0
from tensorflow.keras.layers import (
    AveragePooling2D,
    AvgPool2D,
    Conv2D,
    Dense,
    Flatten,
    GlobalAveragePooling2D,
    MaxPooling2D,
)
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tqdm import notebook, tqdm

# %%
PATH = "/app/_data/"
PATH_JSON1 = '/app/_data/json/1071_big.json'
PATH_JSON2 = '/app/_data/json/part_2_bb.json'
BATCH_SIZE = 64
SEED = 37
IMAGE_SIZE = 224
NUM_CLASSES = 6
TRAIN_IMG_PATH = "/app/_data/train_images/"
TEST_IMG_PATH = "/app/_data/test_images/"

# %%
labels = pd.read_csv(PATH + "train_labels.csv")
sample_submission = pd.read_csv(PATH + "sample_submission.csv")
labels = labels.join(labels["labels"].str.get_dummies(sep=" "))
feature_columns = labels.columns[2:].tolist()
labels_2020 = pd.read_csv(PATH + "train_20.csv")
labels_2020["image_id"] = labels_2020["image_id"] + ".jpg"
labels_2020.columns = ["image", "healthy", "complex", "rust", "scab"]
labels_2020 = labels_2020.query("complex !=1").reset_index(drop=True)
labels_2020 = labels_2020[["image", "healthy", "rust", "scab"]]
feature_columns_20 = ["healthy", "rust", "scab"]
for i in labels_2020.index:
    labels_2020.loc[i, "labels_20"] = "".join(
        list(
            map(
                lambda x, y: x * y,
                labels_2020.loc[i, feature_columns_20].values,
                feature_columns_20,
            )
        )
    )
labels_21_20 = pd.concat([labels, labels_2020], axis=0, join="outer", ignore_index=True)
labels_21_20[feature_columns] = labels_21_20[feature_columns].fillna(0).astype("int")
labels_21_20["labels"] = labels_21_20["labels"].fillna(labels_21_20["labels_20"])
labels_21_20 = labels_21_20.drop("labels_20", axis=1)
labels_21_20.head(2)
# Out:
#                   image                           labels  complex  \
# 0  800113bb65efe69e.jpg                          healthy        0
# 1  8002cb321f8bfcdf.jpg  scab frog_eye_leaf_spot complex        1
#
#    frog_eye_leaf_spot  healthy  powdery_mildew  rust  scab
# 0                   0        1               0     0     0
# 1                   1        0               0     0     1

# %%
with open(PATH_JSON1, "r") as read_file:
    data1 = json.load(read_file)
with open(PATH_JSON2, "r") as read_file:
    data2 = json.load(read_file)

# %%
data1.extend(data2)

# %%
len(data1)
# Out:
# 1564

# %%
df = pd.DataFrame()
data = data1
for i in range(len(data)):
  img = data[i]['file_upload'].split('.')[0].split('_')[0]+'.jpg'
  df.loc[img, 'image'] = img
  df.loc[img, 'original_width'] = data[i]['annotations'][0]['result'][0]['original_width']
  df.loc[img, 'original_height'] = data[i]['annotations'][0]['result'][0]['original_height']
  df.loc[img, 'x_min'] = data[i]['annotations'][0]['result'][0]['value']['x']
  df.loc[img, 'y_min'] = data[i]['annotations'][0]['result'][0]['value']['y']
  df.loc[img, 'width'] = data[i]['annotations'][0]['result'][0]['value']['width']
  df.loc[img, 'height'] = data[i]['annotations'][0]['result'][0]['value']['height']
  df.loc[img, 'rotation'] = data[i]['annotations'][0]['result'][0]['value']['rotation']

# %%
df['image'].duplicated().sum()
# Out:
# 0

# %%
col_coord = ['x_min', 'y_min', 'width', 'height']
def get_real_coord1(coord, img_width, img_height):
    x0 = coord[0]
    y0 = coord[1]
    width = coord[2]
    height = coord[3]
    pixel_x = x0 / 100.0 * img_width
    pixel_y = y0 / 100.0 * img_height
    pixel_width = width / 100.0 * img_width
    pixel_height = height / 100.0 * img_height
    return [pixel_x, pixel_y, pixel_width, pixel_height]

def get_real_coord2(coord, img_width, img_height):
    x0 = coord[0]
    y0 = coord[1]
    width = coord[2]
    height = coord[3]
    x_min = x0 / 100.0 * img_width
    y_min = y0 / 100.0 * img_height
    pixel_width = width / 100.0 * img_width
    pixel_height = height / 100.0 * img_height
    x_max = x_min + pixel_width
    y_max = y_min + pixel_height
    return [x_min, y_min, x_max, y_max]

def get_percent_coord(coord):
    x0 = coord[0]
    y0 = coord[1]
    width = coord[2]
    height = coord[3]
    x_min = x0
    y_min = y0
    x_max = x0 + width
    y_max = y0 + height
    return [x_min, y_min, x_max, y_max]

# %%
get_real_coord2(df[col_coord].values[0], 1000, 1000)
(get_percent_coord(df[col_coord].values[0]))
# Out:
# [0.0, 157.76582834147987, 973.3333333333331, 850.2994011976051]
# [0.0, 15.776582834147987, 97.33333333333331, 85.02994011976051]

# %%
for i in df.index:
    coord = get_percent_coord(df.loc[i, col_coord].values)
    df.loc[i, 'x_max'] = coord[2]
    df.loc[i, 'y_max'] = coord[3]

# %%
xy_columns = ['x_min', 'y_min', 'x_max', 'y_max']

# %%
df[xy_columns] = df[xy_columns]/100

# %%
gen = ImageDataGenerator(validation_split=0.1)
train = gen.flow_from_dataframe(
    dataframe=df,
    directory=TRAIN_IMG_PATH,
    x_col="image",
    y_col=xy_columns,
    target_size=(IMAGE_SIZE, IMAGE_SIZE),
    batch_size=BATCH_SIZE,
    class_mode="raw",
    interpolation = 'bicubic',
    shuffle=True,
    subset='training', seed=SEED
)
# Out:
# Found 1365 validated image filenames.

# %%
valid = gen.flow_from_dataframe(
    dataframe=df,
    directory=TRAIN_IMG_PATH,
    x_col="image",
    y_col=xy_columns,
    target_size=(IMAGE_SIZE, IMAGE_SIZE),
    batch_size=BATCH_SIZE,
    class_mode="raw",
    interpolation = 'bicubic',
    shuffle=False,
    subset='validation', seed=SEED
)
# Out:
# Found 151 validated image filenames.

# %%
# policy = keras.mixed_precision.experimental.Policy('mixed_float16')
# keras.mixed_precision.experimental.set_policy(policy)

# %%
inputs = keras.Input(shape=(IMAGE_SIZE, IMAGE_SIZE, 3))
base_model = keras.applications.EfficientNetB0(weights='imagenet', include_top=False)
x = base_model(inputs)
x = keras.layers.GlobalAveragePooling2D(name="avg_pool")(x)
x = keras.layers.Flatten(name="flatten")(x)
outputs = keras.layers.Dense(4, activation="sigmoid")(x)
model = keras.Model(inputs=inputs, outputs=outputs)

model.compile(
    loss="mse",
    optimizer=Adam(lr=0.0005),
    metrics='mae',
)

# %%
callbacks = [
    keras.callbacks.EarlyStopping(
        monitor="val_mae", patience=20, restore_best_weights=True, verbose=1, mode='min',
    ),
    keras.callbacks.ModelCheckpoint(
        "/app/_data/models/bb/bb_b0_1516_1.h5",
        monitor="val_mae",
        verbose=1,
        save_best_only=True,
        save_weights_only=False,
        mode="min",
        save_freq="epoch",
    ),
        keras.callbacks.ReduceLROnPlateau(
        monitor="val_mae",
        factor=0.2,
        patience=5,
        verbose=1,
        mode="min",
        min_delta=1e-4,
        min_lr=0.000000001,
    ),
]

# %%
history = model.fit(
    train,
    validation_data=valid,
    epochs=100,
    batch_size = BATCH_SIZE,
    verbose=1,
    use_multiprocessing=True,
    callbacks=callbacks)
# Out:
# Epoch 1/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 21/22 [===========================>..] - ETA: 9s - loss: 0.0359 - mae: 0.1398 WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 22/22 [==============================] - ETA: 0s - loss: 0.0346 - mae: 0.1364WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00001: val_mae improved from inf to 0.10498, saving model to /app/_data/models/bb/bb_b0_1516_1.h5
# 22/22 [==============================] - 245s 11s/step - loss: 0.0346 - mae: 0.1364 - val_loss: 0.0195 - val_mae: 0.1050
# Epoch 2/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 21/22 [===========================>..] - ETA: 9s - loss: 0.0061 - mae: 0.0617 WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 22/22 [==============================] - ETA: 0s - loss: 0.0060 - mae: 0.0613WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00002: val_mae improved from 0.10498 to 0.08671, saving model to /app/_data/models/bb/bb_b0_1516_1.h5
# 22/22 [==============================] - 238s 11s/step - loss: 0.0060 - mae: 0.0613 - val_loss: 0.0124 - val_mae: 0.0867
# Epoch 3/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 21/22 [===========================>..] - ETA: 9s - loss: 0.0038 - mae: 0.0491 WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 22/22 [==============================] - ETA: 0s - loss: 0.0038 - mae: 0.0489WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00003: val_mae improved from 0.08671 to 0.06941, saving model to /app/_data/models/bb/bb_b0_1516_1.h5
# 22/22 [==============================] - 233s 11s/step - loss: 0.0038 - mae: 0.0489 - val_loss: 0.0076 - val_mae: 0.0694
# Epoch 4/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 21/22 [===========================>..] - ETA: 9s - loss: 0.0027 - mae: 0.0415 WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 22/22 [==============================] - ETA: 0s - loss: 0.0028 - mae: 0.0416WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00004: val_mae improved from 0.06941 to 0.06147, saving model to /app/_data/models/bb/bb_b0_1516_1.h5
# 22/22 [==============================] - 235s 11s/step - loss: 0.0028 - mae: 0.0416 - val_loss: 0.0059 - val_mae: 0.0615
# Epoch 5/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 21/22 [===========================>..] - ETA: 9s - loss: 0.0020 - mae: 0.0355 WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 22/22 [==============================] - ETA: 0s - loss: 0.0020 - mae: 0.0355WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00005: val_mae improved from 0.06147 to 0.06068, saving model to /app/_data/models/bb/bb_b0_1516_1.h5
# 22/22 [==============================] - 233s 11s/step - loss: 0.0020 - mae: 0.0355 - val_loss: 0.0056 - val_mae: 0.0607
# Epoch 6/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 21/22 [===========================>..] - ETA: 9s - loss: 0.0016 - mae: 0.0321 WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 22/22 [==============================] - ETA: 0s - loss: 0.0016 - mae: 0.0320WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00006: val_mae improved from 0.06068 to 0.05583, saving model to /app/_data/models/bb/bb_b0_1516_1.h5
# 22/22 [==============================] - 242s 11s/step - loss: 0.0016 - mae: 0.0320 - val_loss: 0.0048 - val_mae: 0.0558
# Epoch 7/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 21/22 [===========================>..] - ETA: 9s - loss: 0.0013 - mae: 0.0287 WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 22/22 [==============================] - ETA: 0s - loss: 0.0013 - mae: 0.0287WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00007: val_mae improved from 0.05583 to 0.05416, saving model to /app/_data/models/bb/bb_b0_1516_1.h5
# 22/22 [==============================] - 243s 11s/step - loss: 0.0013 - mae: 0.0287 - val_loss: 0.0045 - val_mae: 0.0542
# Epoch 8/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 21/22 [===========================>..] - ETA: 9s - loss: 0.0011 - mae: 0.0263 WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 22/22 [==============================] - ETA: 0s - loss: 0.0011 - mae: 0.0262WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00008: val_mae improved from 0.05416 to 0.05061, saving model to /app/_data/models/bb/bb_b0_1516_1.h5
# 22/22 [==============================] - 240s 11s/step - loss: 0.0011 - mae: 0.0262 - val_loss: 0.0040 - val_mae: 0.0506
# Epoch 9/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 21/22 [===========================>..] - ETA: 9s - loss: 0.0010 - mae: 0.0249 WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 22/22 [==============================] - ETA: 0s - loss: 0.0010 - mae: 0.0249WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00009: val_mae improved from 0.05061 to 0.04980, saving model to /app/_data/models/bb/bb_b0_1516_1.h5
# 22/22 [==============================] - 239s 11s/step - loss: 0.0010 - mae: 0.0249 - val_loss: 0.0040 - val_mae: 0.0498
# Epoch 10/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 21/22 [===========================>..] - ETA: 9s - loss: 8.9935e-04 - mae: 0.0237 WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 22/22 [==============================] - ETA: 0s - loss: 9.0197e-04 - mae: 0.0237WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00010: val_mae improved from 0.04980 to 0.04664, saving model to /app/_data/models/bb/bb_b0_1516_1.h5
# 22/22 [==============================] - 245s 11s/step - loss: 9.0197e-04 - mae: 0.0237 - val_loss: 0.0035 - val_mae: 0.0466
# Epoch 11/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 21/22 [===========================>..] - ETA: 9s - loss: 8.4884e-04 - mae: 0.0230 WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 22/22 [==============================] - ETA: 0s - loss: 8.4739e-04 - mae: 0.0230WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00011: val_mae improved from 0.04664 to 0.04549, saving model to /app/_data/models/bb/bb_b0_1516_1.h5
# 22/22 [==============================] - 243s 11s/step - loss: 8.4739e-04 - mae: 0.0230 - val_loss: 0.0034 - val_mae: 0.0455
# Epoch 12/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 21/22 [===========================>..] - ETA: 10s - loss: 8.0127e-04 - mae: 0.0221WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 22/22 [==============================] - ETA: 0s - loss: 8.0856e-04 - mae: 0.0222 WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00012: val_mae improved from 0.04549 to 0.04372, saving model to /app/_data/models/bb/bb_b0_1516_1.h5
# 22/22 [==============================] - 246s 11s/step - loss: 8.0856e-04 - mae: 0.0222 - val_loss: 0.0032 - val_mae: 0.0437
# Epoch 13/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 21/22 [===========================>..] - ETA: 9s - loss: 8.1927e-04 - mae: 0.0223 WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 22/22 [==============================] - ETA: 0s - loss: 8.1824e-04 - mae: 0.0223WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00013: val_mae improved from 0.04372 to 0.04268, saving model to /app/_data/models/bb/bb_b0_1516_1.h5
# 22/22 [==============================] - 234s 11s/step - loss: 8.1824e-04 - mae: 0.0223 - val_loss: 0.0030 - val_mae: 0.0427
# Epoch 14/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 21/22 [===========================>..] - ETA: 9s - loss: 6.9813e-04 - mae: 0.0205 WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 22/22 [==============================] - ETA: 0s - loss: 6.9880e-04 - mae: 0.0206WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00014: val_mae improved from 0.04268 to 0.03987, saving model to /app/_data/models/bb/bb_b0_1516_1.h5
# 22/22 [==============================] - 238s 11s/step - loss: 6.9880e-04 - mae: 0.0206 - val_loss: 0.0027 - val_mae: 0.0399
# Epoch 15/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 21/22 [===========================>..] - ETA: 9s - loss: 6.6747e-04 - mae: 0.0202 WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 22/22 [==============================] - ETA: 0s - loss: 6.6611e-04 - mae: 0.0201WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00015: val_mae did not improve from 0.03987
# 22/22 [==============================] - 239s 11s/step - loss: 6.6611e-04 - mae: 0.0201 - val_loss: 0.0028 - val_mae: 0.0408
# Epoch 16/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 21/22 [===========================>..] - ETA: 9s - loss: 6.1419e-04 - mae: 0.0192 WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 22/22 [==============================] - ETA: 0s - loss: 6.2623e-04 - mae: 0.0194WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00016: val_mae did not improve from 0.03987
# 22/22 [==============================] - 234s 11s/step - loss: 6.2623e-04 - mae: 0.0194 - val_loss: 0.0028 - val_mae: 0.0409
# Epoch 17/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 21/22 [===========================>..] - ETA: 9s - loss: 6.3444e-04 - mae: 0.0196 WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 22/22 [==============================] - ETA: 0s - loss: 6.3197e-04 - mae: 0.0196WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00017: val_mae did not improve from 0.03987
# 22/22 [==============================] - 238s 11s/step - loss: 6.3197e-04 - mae: 0.0196 - val_loss: 0.0028 - val_mae: 0.0408
# Epoch 18/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 21/22 [===========================>..] - ETA: 9s - loss: 5.9812e-04 - mae: 0.0186 WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 22/22 [==============================] - ETA: 0s - loss: 6.0173e-04 - mae: 0.0187WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00018: val_mae improved from 0.03987 to 0.03911, saving model to /app/_data/models/bb/bb_b0_1516_1.h5
# 22/22 [==============================] - 245s 11s/step - loss: 6.0173e-04 - mae: 0.0187 - val_loss: 0.0026 - val_mae: 0.0391
# Epoch 19/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 21/22 [===========================>..] - ETA: 10s - loss: 5.5978e-04 - mae: 0.0183WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 22/22 [==============================] - ETA: 0s - loss: 5.6814e-04 - mae: 0.0184 WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00019: val_mae improved from 0.03911 to 0.03830, saving model to /app/_data/models/bb/bb_b0_1516_1.h5
# 22/22 [==============================] - 244s 11s/step - loss: 5.6814e-04 - mae: 0.0184 - val_loss: 0.0025 - val_mae: 0.0383
# Epoch 20/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 21/22 [===========================>..] - ETA: 9s - loss: 5.1774e-04 - mae: 0.0177 WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 22/22 [==============================] - ETA: 0s - loss: 5.1650e-04 - mae: 0.0176WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00020: val_mae did not improve from 0.03830
# 22/22 [==============================] - 239s 11s/step - loss: 5.1650e-04 - mae: 0.0176 - val_loss: 0.0026 - val_mae: 0.0397
# Epoch 21/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 21/22 [===========================>..] - ETA: 9s - loss: 5.2757e-04 - mae: 0.0177 WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 22/22 [==============================] - ETA: 0s - loss: 5.3600e-04 - mae: 0.0178WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00021: val_mae improved from 0.03830 to 0.03715, saving model to /app/_data/models/bb/bb_b0_1516_1.h5
# 22/22 [==============================] - 230s 10s/step - loss: 5.3600e-04 - mae: 0.0178 - val_loss: 0.0023 - val_mae: 0.0372
# Epoch 22/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 21/22 [===========================>..] - ETA: 10s - loss: 4.9414e-04 - mae: 0.0170WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 22/22 [==============================] - ETA: 0s - loss: 5.0047e-04 - mae: 0.0172 WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00022: val_mae did not improve from 0.03715
# 22/22 [==============================] - 240s 11s/step - loss: 5.0047e-04 - mae: 0.0172 - val_loss: 0.0029 - val_mae: 0.0416
# Epoch 23/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 21/22 [===========================>..] - ETA: 9s - loss: 6.1363e-04 - mae: 0.0190 WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 22/22 [==============================] - ETA: 0s - loss: 6.1912e-04 - mae: 0.0191WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00023: val_mae did not improve from 0.03715
# 22/22 [==============================] - 232s 11s/step - loss: 6.1912e-04 - mae: 0.0191 - val_loss: 0.0025 - val_mae: 0.0384
# Epoch 24/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 21/22 [===========================>..] - ETA: 9s - loss: 5.3396e-04 - mae: 0.0177 WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 22/22 [==============================] - ETA: 0s - loss: 5.3495e-04 - mae: 0.0178WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00024: val_mae did not improve from 0.03715
# 22/22 [==============================] - 241s 11s/step - loss: 5.3495e-04 - mae: 0.0178 - val_loss: 0.0027 - val_mae: 0.0403
# Epoch 25/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 21/22 [===========================>..] - ETA: 9s - loss: 4.7848e-04 - mae: 0.0170 WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 22/22 [==============================] - ETA: 0s - loss: 4.8302e-04 - mae: 0.0171WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00025: val_mae did not improve from 0.03715
# 22/22 [==============================] - 239s 11s/step - loss: 4.8302e-04 - mae: 0.0171 - val_loss: 0.0024 - val_mae: 0.0377
# Epoch 26/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 21/22 [===========================>..] - ETA: 9s - loss: 5.3472e-04 - mae: 0.0178 WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 22/22 [==============================] - ETA: 0s - loss: 5.3829e-04 - mae: 0.0178WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00026: val_mae did not improve from 0.03715
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 22/22 [==============================] - 238s 11s/step - loss: 5.3829e-04 - mae: 0.0178 - val_loss: 0.0027 - val_mae: 0.0392
# Epoch 27/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 21/22 [===========================>..] - ETA: 9s - loss: 4.7366e-04 - mae: 0.0169 WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 22/22 [==============================] - ETA: 0s - loss: 4.7172e-04 - mae: 0.0168WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00027: val_mae improved from 0.03715 to 0.03634, saving model to /app/_data/models/bb/bb_b0_1516_1.h5
# 22/22 [==============================] - 236s 11s/step - loss: 4.7172e-04 - mae: 0.0168 - val_loss: 0.0022 - val_mae: 0.0363
# Epoch 28/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 21/22 [===========================>..] - ETA: 9s - loss: 3.7939e-04 - mae: 0.0150 WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 22/22 [==============================] - ETA: 0s - loss: 3.8119e-04 - mae: 0.0150WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00028: val_mae improved from 0.03634 to 0.03559, saving model to /app/_data/models/bb/bb_b0_1516_1.h5
# 22/22 [==============================] - 230s 10s/step - loss: 3.8119e-04 - mae: 0.0150 - val_loss: 0.0021 - val_mae: 0.0356
# Epoch 29/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 21/22 [===========================>..] - ETA: 9s - loss: 3.3382e-04 - mae: 0.0142 WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 22/22 [==============================] - ETA: 0s - loss: 3.3710e-04 - mae: 0.0143WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00029: val_mae improved from 0.03559 to 0.03416, saving model to /app/_data/models/bb/bb_b0_1516_1.h5
# 22/22 [==============================] - 238s 11s/step - loss: 3.3710e-04 - mae: 0.0143 - val_loss: 0.0020 - val_mae: 0.0342
# Epoch 30/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 21/22 [===========================>..] - ETA: 9s - loss: 3.0404e-04 - mae: 0.0135 WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 22/22 [==============================] - ETA: 0s - loss: 3.0689e-04 - mae: 0.0136WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00030: val_mae did not improve from 0.03416
# 22/22 [==============================] - 229s 10s/step - loss: 3.0689e-04 - mae: 0.0136 - val_loss: 0.0021 - val_mae: 0.0347
# Epoch 31/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 21/22 [===========================>..] - ETA: 9s - loss: 3.1816e-04 - mae: 0.0139 WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 22/22 [==============================] - ETA: 0s - loss: 3.1478e-04 - mae: 0.0138WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00031: val_mae improved from 0.03416 to 0.03384, saving model to /app/_data/models/bb/bb_b0_1516_1.h5
# 22/22 [==============================] - 233s 11s/step - loss: 3.1478e-04 - mae: 0.0138 - val_loss: 0.0020 - val_mae: 0.0338
# Epoch 32/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 21/22 [===========================>..] - ETA: 9s - loss: 3.5692e-04 - mae: 0.0147 WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 22/22 [==============================] - ETA: 0s - loss: 3.6043e-04 - mae: 0.0147WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00032: val_mae improved from 0.03384 to 0.03342, saving model to /app/_data/models/bb/bb_b0_1516_1.h5
# 22/22 [==============================] - 247s 11s/step - loss: 3.6043e-04 - mae: 0.0147 - val_loss: 0.0019 - val_mae: 0.0334
# Epoch 33/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 21/22 [===========================>..] - ETA: 9s - loss: 3.0500e-04 - mae: 0.0136 WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 22/22 [==============================] - ETA: 0s - loss: 3.0091e-04 - mae: 0.0135WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00033: val_mae improved from 0.03342 to 0.03334, saving model to /app/_data/models/bb/bb_b0_1516_1.h5
# 22/22 [==============================] - 238s 11s/step - loss: 3.0091e-04 - mae: 0.0135 - val_loss: 0.0019 - val_mae: 0.0333
# Epoch 34/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 21/22 [===========================>..] - ETA: 9s - loss: 3.1503e-04 - mae: 0.0140 WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 22/22 [==============================] - ETA: 0s - loss: 3.1555e-04 - mae: 0.0140WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00034: val_mae improved from 0.03334 to 0.03309, saving model to /app/_data/models/bb/bb_b0_1516_1.h5
# 22/22 [==============================] - 247s 11s/step - loss: 3.1555e-04 - mae: 0.0140 - val_loss: 0.0019 - val_mae: 0.0331
# Epoch 35/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 21/22 [===========================>..] - ETA: 9s - loss: 3.0575e-04 - mae: 0.0135 WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 22/22 [==============================] - ETA: 0s - loss: 3.0149e-04 - mae: 0.0134WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00035: val_mae improved from 0.03309 to 0.03288, saving model to /app/_data/models/bb/bb_b0_1516_1.h5
# 22/22 [==============================] - 239s 11s/step - loss: 3.0149e-04 - mae: 0.0134 - val_loss: 0.0018 - val_mae: 0.0329
# Epoch 36/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 21/22 [===========================>..] - ETA: 9s - loss: 3.0389e-04 - mae: 0.0135 WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 22/22 [==============================] - ETA: 0s - loss: 3.0158e-04 - mae: 0.0134WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00036: val_mae improved from 0.03288 to 0.03252, saving model to /app/_data/models/bb/bb_b0_1516_1.h5
# 22/22 [==============================] - 239s 11s/step - loss: 3.0158e-04 - mae: 0.0134 - val_loss: 0.0018 - val_mae: 0.0325
# Epoch 37/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 21/22 [===========================>..] - ETA: 9s - loss: 3.1236e-04 - mae: 0.0139 WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 22/22 [==============================] - ETA: 0s - loss: 3.1620e-04 - mae: 0.0140WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00037: val_mae improved from 0.03252 to 0.03218, saving model to /app/_data/models/bb/bb_b0_1516_1.h5
# 22/22 [==============================] - 241s 11s/step - loss: 3.1620e-04 - mae: 0.0140 - val_loss: 0.0018 - val_mae: 0.0322
# Epoch 38/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 21/22 [===========================>..] - ETA: 9s - loss: 3.3722e-04 - mae: 0.0142 WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 22/22 [==============================] - ETA: 0s - loss: 3.3152e-04 - mae: 0.0141WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00038: val_mae did not improve from 0.03218
# 22/22 [==============================] - 240s 11s/step - loss: 3.3152e-04 - mae: 0.0141 - val_loss: 0.0018 - val_mae: 0.0326
# Epoch 39/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 21/22 [===========================>..] - ETA: 10s - loss: 3.1736e-04 - mae: 0.0140WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 22/22 [==============================] - ETA: 0s - loss: 3.1834e-04 - mae: 0.0140 WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00039: val_mae did not improve from 0.03218
# 22/22 [==============================] - 253s 11s/step - loss: 3.1834e-04 - mae: 0.0140 - val_loss: 0.0018 - val_mae: 0.0327
# Epoch 40/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 21/22 [===========================>..] - ETA: 9s - loss: 3.1855e-04 - mae: 0.0136 WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 22/22 [==============================] - ETA: 0s - loss: 3.1955e-04 - mae: 0.0137WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00040: val_mae did not improve from 0.03218
# 22/22 [==============================] - 229s 10s/step - loss: 3.1955e-04 - mae: 0.0137 - val_loss: 0.0018 - val_mae: 0.0327
# Epoch 41/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 21/22 [===========================>..] - ETA: 9s - loss: 2.9050e-04 - mae: 0.0133 WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 22/22 [==============================] - ETA: 0s - loss: 2.9116e-04 - mae: 0.0134WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00041: val_mae did not improve from 0.03218
# 22/22 [==============================] - 231s 10s/step - loss: 2.9116e-04 - mae: 0.0134 - val_loss: 0.0018 - val_mae: 0.0326
# Epoch 42/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 21/22 [===========================>..] - ETA: 9s - loss: 3.3318e-04 - mae: 0.0141 WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 22/22 [==============================] - ETA: 0s - loss: 3.3167e-04 - mae: 0.0141WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00042: val_mae improved from 0.03218 to 0.03197, saving model to /app/_data/models/bb/bb_b0_1516_1.h5
# 22/22 [==============================] - 233s 11s/step - loss: 3.3167e-04 - mae: 0.0141 - val_loss: 0.0017 - val_mae: 0.0320
# Epoch 43/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 21/22 [===========================>..] - ETA: 9s - loss: 3.0920e-04 - mae: 0.0136 WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 22/22 [==============================] - ETA: 0s - loss: 3.0847e-04 - mae: 0.0137WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00043: val_mae did not improve from 0.03197
# 22/22 [==============================] - 241s 11s/step - loss: 3.0847e-04 - mae: 0.0137 - val_loss: 0.0018 - val_mae: 0.0323
# Epoch 44/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 21/22 [===========================>..] - ETA: 9s - loss: 2.9725e-04 - mae: 0.0134 WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 22/22 [==============================] - ETA: 0s - loss: 2.9359e-04 - mae: 0.0133WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00044: val_mae improved from 0.03197 to 0.03164, saving model to /app/_data/models/bb/bb_b0_1516_1.h5
# 22/22 [==============================] - 232s 11s/step - loss: 2.9359e-04 - mae: 0.0133 - val_loss: 0.0017 - val_mae: 0.0316
# Epoch 45/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 21/22 [===========================>..] - ETA: 9s - loss: 2.8441e-04 - mae: 0.0132 WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 22/22 [==============================] - ETA: 0s - loss: 2.9009e-04 - mae: 0.0133WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00045: val_mae did not improve from 0.03164
# 22/22 [==============================] - 233s 11s/step - loss: 2.9009e-04 - mae: 0.0133 - val_loss: 0.0017 - val_mae: 0.0318
# Epoch 46/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 21/22 [===========================>..] - ETA: 9s - loss: 2.7355e-04 - mae: 0.0129 WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 22/22 [==============================] - ETA: 0s - loss: 2.6920e-04 - mae: 0.0128WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00046: val_mae improved from 0.03164 to 0.03162, saving model to /app/_data/models/bb/bb_b0_1516_1.h5
# 22/22 [==============================] - 235s 11s/step - loss: 2.6920e-04 - mae: 0.0128 - val_loss: 0.0017 - val_mae: 0.0316
# Epoch 47/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 21/22 [===========================>..] - ETA: 9s - loss: 2.9687e-04 - mae: 0.0133 WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 22/22 [==============================] - ETA: 0s - loss: 3.0918e-04 - mae: 0.0137WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00047: val_mae improved from 0.03162 to 0.03130, saving model to /app/_data/models/bb/bb_b0_1516_1.h5
# 22/22 [==============================] - 232s 11s/step - loss: 3.0918e-04 - mae: 0.0137 - val_loss: 0.0017 - val_mae: 0.0313
# Epoch 48/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 21/22 [===========================>..] - ETA: 9s - loss: 2.9479e-04 - mae: 0.0134 WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 22/22 [==============================] - ETA: 0s - loss: 2.9274e-04 - mae: 0.0134WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00048: val_mae improved from 0.03130 to 0.03121, saving model to /app/_data/models/bb/bb_b0_1516_1.h5
# 22/22 [==============================] - 241s 11s/step - loss: 2.9274e-04 - mae: 0.0134 - val_loss: 0.0017 - val_mae: 0.0312
# Epoch 49/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 21/22 [===========================>..] - ETA: 9s - loss: 2.9646e-04 - mae: 0.0135 WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 22/22 [==============================] - ETA: 0s - loss: 2.9319e-04 - mae: 0.0134WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00049: val_mae did not improve from 0.03121
# 22/22 [==============================] - 236s 11s/step - loss: 2.9319e-04 - mae: 0.0134 - val_loss: 0.0017 - val_mae: 0.0316
# Epoch 50/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 21/22 [===========================>..] - ETA: 9s - loss: 2.3943e-04 - mae: 0.0119 WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 22/22 [==============================] - ETA: 0s - loss: 2.4044e-04 - mae: 0.0119WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00050: val_mae did not improve from 0.03121
# 22/22 [==============================] - 244s 11s/step - loss: 2.4044e-04 - mae: 0.0119 - val_loss: 0.0018 - val_mae: 0.0318
# Epoch 51/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 21/22 [===========================>..] - ETA: 9s - loss: 2.9494e-04 - mae: 0.0132 WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 22/22 [==============================] - ETA: 0s - loss: 2.8963e-04 - mae: 0.0130WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00051: val_mae did not improve from 0.03121
# 22/22 [==============================] - 234s 11s/step - loss: 2.8963e-04 - mae: 0.0130 - val_loss: 0.0018 - val_mae: 0.0317
# Epoch 52/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 21/22 [===========================>..] - ETA: 9s - loss: 2.4931e-04 - mae: 0.0124 WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 22/22 [==============================] - ETA: 0s - loss: 2.5140e-04 - mae: 0.0124WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00052: val_mae did not improve from 0.03121
#
# Epoch 00052: ReduceLROnPlateau reducing learning rate to 2.0000000949949027e-05.
# 22/22 [==============================] - 230s 10s/step - loss: 2.5140e-04 - mae: 0.0124 - val_loss: 0.0017 - val_mae: 0.0316
# Epoch 53/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 21/22 [===========================>..] - ETA: 9s - loss: 2.7175e-04 - mae: 0.0129 WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 22/22 [==============================] - ETA: 0s - loss: 2.7232e-04 - mae: 0.0130WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00053: val_mae did not improve from 0.03121
# 22/22 [==============================] - 234s 11s/step - loss: 2.7232e-04 - mae: 0.0130 - val_loss: 0.0017 - val_mae: 0.0312
# Epoch 54/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 21/22 [===========================>..] - ETA: 9s - loss: 2.4712e-04 - mae: 0.0122 WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 22/22 [==============================] - ETA: 0s - loss: 2.4756e-04 - mae: 0.0122WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00054: val_mae improved from 0.03121 to 0.03112, saving model to /app/_data/models/bb/bb_b0_1516_1.h5
# 22/22 [==============================] - 233s 11s/step - loss: 2.4756e-04 - mae: 0.0122 - val_loss: 0.0017 - val_mae: 0.0311
# Epoch 55/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 21/22 [===========================>..] - ETA: 9s - loss: 2.5284e-04 - mae: 0.0122 WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 22/22 [==============================] - ETA: 0s - loss: 2.5630e-04 - mae: 0.0123WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00055: val_mae improved from 0.03112 to 0.03080, saving model to /app/_data/models/bb/bb_b0_1516_1.h5
# 22/22 [==============================] - 240s 11s/step - loss: 2.5630e-04 - mae: 0.0123 - val_loss: 0.0016 - val_mae: 0.0308
# Epoch 56/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 21/22 [===========================>..] - ETA: 9s - loss: 2.3110e-04 - mae: 0.0119 WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 22/22 [==============================] - ETA: 0s - loss: 2.3231e-04 - mae: 0.0120WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00056: val_mae did not improve from 0.03080
# 22/22 [==============================] - 239s 11s/step - loss: 2.3231e-04 - mae: 0.0120 - val_loss: 0.0017 - val_mae: 0.0310
# Epoch 57/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 21/22 [===========================>..] - ETA: 9s - loss: 2.4870e-04 - mae: 0.0122 WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 22/22 [==============================] - ETA: 0s - loss: 2.4862e-04 - mae: 0.0122WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00057: val_mae improved from 0.03080 to 0.03076, saving model to /app/_data/models/bb/bb_b0_1516_1.h5
# 22/22 [==============================] - 231s 10s/step - loss: 2.4862e-04 - mae: 0.0122 - val_loss: 0.0016 - val_mae: 0.0308
# Epoch 58/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 21/22 [===========================>..] - ETA: 9s - loss: 2.3848e-04 - mae: 0.0120 WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 22/22 [==============================] - ETA: 0s - loss: 2.3674e-04 - mae: 0.0120WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00058: val_mae improved from 0.03076 to 0.03056, saving model to /app/_data/models/bb/bb_b0_1516_1.h5
# 22/22 [==============================] - 237s 11s/step - loss: 2.3674e-04 - mae: 0.0120 - val_loss: 0.0016 - val_mae: 0.0306
# Epoch 59/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 21/22 [===========================>..] - ETA: 9s - loss: 2.5362e-04 - mae: 0.0124 WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 22/22 [==============================] - ETA: 0s - loss: 2.5094e-04 - mae: 0.0124WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00059: val_mae did not improve from 0.03056
# 22/22 [==============================] - 230s 10s/step - loss: 2.5094e-04 - mae: 0.0124 - val_loss: 0.0016 - val_mae: 0.0307
# Epoch 60/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 21/22 [===========================>..] - ETA: 9s - loss: 2.2498e-04 - mae: 0.0117 WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 22/22 [==============================] - ETA: 0s - loss: 2.2918e-04 - mae: 0.0118WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00060: val_mae improved from 0.03056 to 0.03054, saving model to /app/_data/models/bb/bb_b0_1516_1.h5
# 22/22 [==============================] - 246s 11s/step - loss: 2.2918e-04 - mae: 0.0118 - val_loss: 0.0016 - val_mae: 0.0305
# Epoch 61/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 21/22 [===========================>..] - ETA: 9s - loss: 2.2700e-04 - mae: 0.0117 WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 22/22 [==============================] - ETA: 0s - loss: 2.2472e-04 - mae: 0.0116WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00061: val_mae improved from 0.03054 to 0.03043, saving model to /app/_data/models/bb/bb_b0_1516_1.h5
# 22/22 [==============================] - 239s 11s/step - loss: 2.2472e-04 - mae: 0.0116 - val_loss: 0.0016 - val_mae: 0.0304
# Epoch 62/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 21/22 [===========================>..] - ETA: 9s - loss: 2.3815e-04 - mae: 0.0120 WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 22/22 [==============================] - ETA: 0s - loss: 2.4186e-04 - mae: 0.0121WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00062: val_mae improved from 0.03043 to 0.03041, saving model to /app/_data/models/bb/bb_b0_1516_1.h5
# 22/22 [==============================] - 236s 11s/step - loss: 2.4186e-04 - mae: 0.0121 - val_loss: 0.0016 - val_mae: 0.0304
# Epoch 63/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 21/22 [===========================>..] - ETA: 9s - loss: 2.4713e-04 - mae: 0.0121 WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 22/22 [==============================] - ETA: 0s - loss: 2.4330e-04 - mae: 0.0120WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00063: val_mae did not improve from 0.03041
# 22/22 [==============================] - 238s 11s/step - loss: 2.4330e-04 - mae: 0.0120 - val_loss: 0.0016 - val_mae: 0.0306
# Epoch 64/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 21/22 [===========================>..] - ETA: 9s - loss: 2.3766e-04 - mae: 0.0120 WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 22/22 [==============================] - ETA: 0s - loss: 2.3524e-04 - mae: 0.0119WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00064: val_mae did not improve from 0.03041
# 22/22 [==============================] - 242s 11s/step - loss: 2.3524e-04 - mae: 0.0119 - val_loss: 0.0016 - val_mae: 0.0305
# Epoch 65/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 20/22 [==========================>...] - ETA: 19s - loss: 2.5536e-04 - mae: 0.0125
