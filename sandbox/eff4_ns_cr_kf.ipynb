# %%
import os

import numpy as np
import pandas as pd
from IPython.core.interactiveshell import InteractiveShell

InteractiveShell.ast_node_interactivity = "all"
import warnings

warnings.filterwarnings("ignore")

import matplotlib.pyplot as plt

# %matplotlib inline

import sklearn
import tensorflow as tf
import tensorflow_addons as tfa
from PIL import Image

from sklearn.model_selection import (
    StratifiedKFold,
    StratifiedShuffleSplit,
    train_test_split,
)
from tensorflow import keras
from tensorflow.keras.applications.efficientnet import EfficientNetB4, EfficientNetB7
from tensorflow.keras.layers import (
    AveragePooling2D,
    AvgPool2D,
    Conv2D,
    Dense,
    Flatten,
    GlobalAveragePooling2D,
    MaxPooling2D,
)
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tqdm import notebook, tqdm

# %%
PATH = "/app/_data/"
BATCH_SIZE = 16
SEED = 1488
IMAGE_SIZE = 380
NUM_CLASSES = 6
TRAIN_IMG_PATH = "/app/_data/cropped_all_v1/"
TEST_IMG_PATH = "/app/_data/test_images/"

# %%
labels = pd.read_csv('../_data/df_csv/labels_21_20_plus_test20_without_complex.csv', index_col=[0])
feature_columns = ['complex', 'frog_eye_leaf_spot', 'healthy', 'powdery_mildew', 'rust', 'scab']

# %%
labels = labels.dropna(axis=0).reset_index(drop=True)

# %% [markdown]
# ### StratifiedShuffleSplit

# %% [markdown]
#  - v1 - labels_long_1 0.812+scab
#  - v2 - labels_21_20 - 0,78 + scab
#  - v3 - labels+all_wrong*4 0.574 +scab
#  - v3 - labels + upsampling

# %%
train, valid = train_test_split(labels, train_size=0.9, random_state=42)

# %%
train["labels"].value_counts(normalize=True)
# Out:
# scab                                       0.283167
# healthy                                    0.244503
# frog_eye_leaf_spot                         0.150605
# rust                                       0.118674
# complex                                    0.075487
# powdery_mildew                             0.056023
# scab frog_eye_leaf_spot                    0.034719
# scab frog_eye_leaf_spot complex            0.009521
# frog_eye_leaf_spot complex                 0.007575
# rust frog_eye_leaf_spot                    0.006102
# rust complex                               0.004419
# powdery_mildew complex                     0.003682
# scab                                       0.002578
# scab rust                                  0.001631
# scab rust frog_eye_leaf_spot               0.000684
# scab frog_eye_leaf_spot                    0.000421
# scab powdery_mildew                        0.000105
# rust                                       0.000053
# scab frog_eye_leaf_spot powdery_mildew     0.000053
# Name: labels, dtype: float64

# %%
valid["labels"].value_counts(normalize=True)
# Out:
# scab                               0.288689
# healthy                            0.247989
# frog_eye_leaf_spot                 0.148131
# rust                               0.115476
# complex                            0.067203
# powdery_mildew                     0.056318
# scab frog_eye_leaf_spot            0.033128
# frog_eye_leaf_spot complex         0.009938
# scab frog_eye_leaf_spot complex    0.008992
# powdery_mildew complex             0.008045
# rust frog_eye_leaf_spot            0.007572
# rust complex                       0.003313
# scab                               0.001893
# scab rust                          0.001420
# scab rust frog_eye_leaf_spot       0.001420
# scab powdery_mildew                0.000473
# Name: labels, dtype: float64

# %%
def pred_to_labels(pred, thresh=0.5, labels=feature_columns):
    pred = [labels[i] for i in range(len(labels)) if pred[i] > thresh]
    pred = " ".join(pred)
    return pred

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
data_augmentation = keras.Sequential(
    [
        keras.layers.experimental.preprocessing.RandomFlip(
            "horizontal_and_vertical", seed=SEED
        ),
        keras.layers.experimental.preprocessing.RandomRotation(0.5, seed=SEED),
        keras.layers.experimental.preprocessing.RandomZoom(0.1, 0.1, seed=SEED),
        keras.layers.experimental.preprocessing.RandomContrast(factor=0.3, seed=SEED),
        keras.layers.experimental.preprocessing.RandomTranslation(
            height_factor=0.1, width_factor=0.1, seed=SEED
        ),
    ]
)

# %%
# df_crop1 = pd.read_csv(PATH+'df_boxes.csv')
# df_crop2 = pd.read_csv(PATH+'df_boxes_20.csv')
# df_crop1.columns = ['image', 'x_min', 'y_min', 'x_max', 'y_max']
# df_crop2.columns = ['image', 'x_min', 'y_min', 'x_max', 'y_max']
# df_crop = pd.concat([df_crop1, df_crop2], axis=0, ignore_index=True)
# def write_np(file_path):
#     img = tf.io.read_file(PATH + 'train_images/'+ file_path)
#     img = tf.image.decode_jpeg(img, channels=3)
#     coord = df_crop[df_crop["image"] == file_path][['x_min', 'y_min', 'x_max', 'y_max']].values[0]
#     orig_hight = img.shape[0]
#     orig_width = img.shape[1]
#     x_min = coord[0]
#     y_min = coord[1]
#     x_max = coord[2]
#     y_max = coord[3]
#     cropped_image = img.numpy()[np.int(y_min*orig_hight):np.int(y_max*orig_hight),np.int(x_min*orig_width):np.int(x_max*orig_width)]
#     img = tf.image.resize(cropped_image, (600, 600))
#     img = tf.cast(img, dtype='uint8')
#     img = Image.fromarray(img.numpy())
#     img.save(PATH + 'cropped_all_600_v1/'+file_path)
# #     return img
# # labels_21_20['image'].apply(write_np)
# all_imgs = os.listdir(PATH + 'train_images/')
# for i in tqdm(range(len(all_imgs))):
#     if all_imgs[i] in df_crop["image"].values:
#          write_np(all_imgs[i])

# %%
len(os.listdir(TRAIN_IMG_PATH))
# Out:
# 21221

# %%
# from 380 uint8
def parse_image(file_path):
    img = tf.io.read_file(TRAIN_IMG_PATH + file_path)
    img = tf.image.decode_jpeg(img, channels=3)
    return img

# %%
plt.imshow(parse_image(os.listdir(PATH + "cropped_all_600_v1/")[55]))

# %%
def prepare_dataset(df, augmentation=False):
    dataset = tf.data.Dataset.from_tensor_slices(
        (df["image"].values, df[feature_columns].astype("uint8").values)
    )
    dataset = dataset.map(lambda x, y: (parse_image(x), y))
    dataset = dataset.batch(BATCH_SIZE)

    if augmentation:
        dataset = dataset.map(
            lambda x, y: (data_augmentation(x, training=True), y),
            num_parallel_calls=AUTOTUNE,
        )
    dataset = dataset.repeat().prefetch(buffer_size=AUTOTUNE)
    return dataset

# %%
ds_train = prepare_dataset(train, augmentation=True)
ds_valid = prepare_dataset(valid)

# %%
for a, b in ds_train.take(1):
    print(a[0].dtype, b.dtype)
    print(a[0].shape, b.shape)
# Out:
# <dtype: 'uint8'> <dtype: 'uint8'>
# (380, 380, 3) (16, 6)

# %%
plt.imshow(a[0])

# %%
def parse_test_image(img_name):
    img = tf.io.read_file(img_name)
    img = tf.image.decode_jpeg(img, channels=3)
    img = tf.image.convert_image_dtype(img, tf.float32)
    img = tf.image.resize(
        img,
        IMAGE_SIZE,
    )
    img = tf.image.convert_image_dtype(img, tf.uint8)
    return img
def predict_new(path, model):
    img = parse_test_image(path)
    img = tf.expand_dims(img, axis=0)
    pred = model.predict(img)
    return pred_to_labels(pred[0])

# %%
policy = keras.mixed_precision.experimental.Policy('mixed_float16')
keras.mixed_precision.experimental.set_policy(policy)
# Out:
# INFO:tensorflow:Mixed precision compatibility check (mixed_float16): OK
# Your GPU will likely run quickly with dtype policy mixed_float16 as it has compute capability of at least 7.0. Your GPU: Quadro RTX 5000, compute capability 7.5

# %%
callbacks = [
    keras.callbacks.EarlyStopping(
        monitor="val_f1_score",
        patience=10,
        restore_best_weights=True,
        verbose=1,
        mode="max",
    ),
#     keras.callbacks.ModelCheckpoint(
#         "/app/_data/models/new/eff4_ns_cropped_3.h5",
#         monitor="val_f1_score",
#         verbose=1,
#         save_best_only=True,
#         save_weights_only=False,
#         mode="max",
#         save_freq="epoch",
#     ),
#     keras.callbacks.ReduceLROnPlateau(
#         monitor="val_f1_score",
#         factor=0.2,
#         patience=3,
#         verbose=1,
#         mode="max",
#         min_delta=1e-4,
#         min_lr=0.00000001,
#     ),
]

# %%
# base_model = keras.applications.EfficientNetB4(weights=None, include_top=False)
# base_model.load_weights('/app/_data/models/efficientnet-b4_noisy-student_notop.h5', by_name=True, skip_mismatch = True)

# %%
inputs = keras.Input(shape=(IMAGE_SIZE, IMAGE_SIZE,3))
base_model = keras.applications.EfficientNetB4(weights=None, include_top=False)
base_model.load_weights(
    "/app/_data/models/efficientnet-b4_noisy-student_notop.h5",
    by_name=True,
    skip_mismatch=True,
)
x = base_model(inputs)
x = keras.layers.GlobalAveragePooling2D(name="avg_pool")(x)
x = keras.layers.Flatten(name="flatten")(x)
outputs = keras.layers.Dense(NUM_CLASSES, activation="sigmoid")(x)
model_eff = keras.Model(inputs=inputs, outputs=outputs)

# %%
skf = StratifiedKFold(n_splits=5, random_state=SEED, shuffle=True)
X = labels["image"]
y = labels[feature_columns]
for i, (train_index, valid_index) in enumerate(skf.split(labels["image"], labels['labels'])):
    train, valid = labels.loc[train_index], labels.loc[valid_index]
    model_name = 'eff4_ns_cr_kf_' + str(i+1) + '.h5'
    ds_train = prepare_dataset(train, augmentation = True)
    ds_valid = prepare_dataset(valid)
    model = model_eff
    model.compile(
    loss="binary_crossentropy",
    optimizer=Adam(lr=0.0005),
    metrics=[
        "acc",
        keras.metrics.Recall(),
        keras.metrics.Precision(),
        tfa.metrics.F1Score(num_classes=NUM_CLASSES, average="micro"),
    ],
)
    history = model.fit(
    ds_train,
    validation_data=ds_valid,
    epochs=100,
    steps_per_epoch=(train.shape[0]*0.9)//BATCH_SIZE,
    validation_steps= (valid.shape[0]*0.1)//BATCH_SIZE,
    verbose=1,
    use_multiprocessing=True,
    callbacks = callbacks
)
    model.save("/app/_data/models/"+model_name)
# Out:
# Epoch 1/100
# 950/950 [==============================] - 320s 337ms/step - loss: 0.0314 - acc: 0.9504 - recall_3: 0.9651 - precision_3: 0.9720 - f1_score: 0.9483 - val_loss: 0.0638 - val_acc: 0.9255 - val_recall_3: 0.9503 - val_precision_3: 0.9232 - val_f1_score: 0.9258
# Epoch 4/100
# 950/950 [==============================] - 320s 337ms/step - loss: 0.0269 - acc: 0.9529 - recall_3: 0.9700 - precision_3: 0.9742 - f1_score: 0.9502 - val_loss: 0.0639 - val_acc: 0.9399 - val_recall_3: 0.9300 - val_precision_3: 0.9406 - val_f1_score: 0.9302
# Epoch 5/100
# 950/950 [==============================] - 320s 336ms/step - loss: 0.0263 - acc: 0.9517 - recall_3: 0.9697 - precision_3: 0.9762 - f1_score: 0.9503 - val_loss: 0.0850 - val_acc: 0.9399 - val_recall_3: 0.9413 - val_precision_3: 0.9456 - val_f1_score: 0.9384
# Epoch 6/100
# 950/950 [==============================] - 320s 337ms/step - loss: 0.0237 - acc: 0.9534 - recall_3: 0.9730 - precision_3: 0.9783 - f1_score: 0.9525 - val_loss: 0.0595 - val_acc: 0.9495 - val_recall_3: 0.9413 - val_precision_3: 0.9586 - val_f1_score: 0.9408
# Epoch 7/100
# 950/950 [==============================] - 320s 337ms/step - loss: 0.0223 - acc: 0.9549 - recall_3: 0.9755 - precision_3: 0.9797 - f1_score: 0.9540 - val_loss: 0.0672 - val_acc: 0.9567 - val_recall_3: 0.9481 - val_precision_3: 0.9567 - val_f1_score: 0.9479
# Epoch 8/100
# 950/950 [==============================] - 321s 337ms/step - loss: 0.0227 - acc: 0.9550 - recall_3: 0.9750 - precision_3: 0.9780 - f1_score: 0.9533 - val_loss: 0.1109 - val_acc: 0.9135 - val_recall_3: 0.9210 - val_precision_3: 0.9294 - val_f1_score: 0.9163
# Epoch 9/100
# 950/950 [==============================] - 320s 337ms/step - loss: 0.0210 - acc: 0.9567 - recall_3: 0.9762 - precision_3: 0.9803 - f1_score: 0.9540 - val_loss: 0.0971 - val_acc: 0.9327 - val_recall_3: 0.9278 - val_precision_3: 0.9174 - val_f1_score: 0.9199
# Epoch 10/100
# 950/950 [==============================] - 320s 337ms/step - loss: 0.0183 - acc: 0.9618 - recall_3: 0.9811 - precision_3: 0.9827 - f1_score: 0.9577 - val_loss: 0.2484 - val_acc: 0.8510 - val_recall_3: 0.7991 - val_precision_3: 0.8894 - val_f1_score: 0.8452
# Epoch 11/100
# 950/950 [==============================] - 320s 337ms/step - loss: 0.0209 - acc: 0.9571 - recall_3: 0.9769 - precision_3: 0.9808 - f1_score: 0.9533 - val_loss: 0.1062 - val_acc: 0.9111 - val_recall_3: 0.9165 - val_precision_3: 0.9206 - val_f1_score: 0.9082
# Epoch 12/100
# 950/950 [==============================] - 318s 335ms/step - loss: 0.0167 - acc: 0.9577 - recall_3: 0.9815 - precision_3: 0.9836 - f1_score: 0.9578 - val_loss: 0.0743 - val_acc: 0.9375 - val_recall_3: 0.9436 - val_precision_3: 0.9457 - val_f1_score: 0.9349
# Epoch 13/100
# 950/950 [==============================] - 319s 336ms/step - loss: 0.0164 - acc: 0.9602 - recall_3: 0.9824 - precision_3: 0.9852 - f1_score: 0.9597 - val_loss: 0.0790 - val_acc: 0.9471 - val_recall_3: 0.9436 - val_precision_3: 0.9351 - val_f1_score: 0.9397
# Epoch 14/100
# 950/950 [==============================] - 320s 336ms/step - loss: 0.0173 - acc: 0.9567 - recall_3: 0.9826 - precision_3: 0.9847 - f1_score: 0.9584 - val_loss: 0.0681 - val_acc: 0.9495 - val_recall_3: 0.9458 - val_precision_3: 0.9588 - val_f1_score: 0.9444
# Epoch 15/100
# 950/950 [==============================] - 320s 337ms/step - loss: 0.0175 - acc: 0.9593 - recall_3: 0.9809 - precision_3: 0.9845 - f1_score: 0.9583 - val_loss: 0.1049 - val_acc: 0.9375 - val_recall_3: 0.9278 - val_precision_3: 0.9405 - val_f1_score: 0.9338
# Epoch 16/100
# 950/950 [==============================] - 320s 337ms/step - loss: 0.0152 - acc: 0.9609 - recall_3: 0.9836 - precision_3: 0.9854 - f1_score: 0.9597 - val_loss: 0.0757 - val_acc: 0.9471 - val_recall_3: 0.9436 - val_precision_3: 0.9457 - val_f1_score: 0.9397
# Epoch 17/100
# 950/950 [==============================] - ETA: 0s - loss: 0.0150 - acc: 0.9606 - recall_3: 0.9841 - precision_3: 0.9868 - f1_score: 0.9609Restoring model weights from the end of the best epoch.
# 950/950 [==============================] - 321s 337ms/step - loss: 0.0150 - acc: 0.9606 - recall_3: 0.9841 - precision_3: 0.9868 - f1_score: 0.9609 - val_loss: 0.0790 - val_acc: 0.9423 - val_recall_3: 0.9368 - val_precision_3: 0.9562 - val_f1_score: 0.9397
# Epoch 00017: early stopping
# Epoch 1/100
# 950/950 [==============================] - 324s 341ms/step - loss: 0.0357 - acc: 0.9488 - recall_4: 0.9610 - precision_4: 0.9666 - f1_score: 0.9417 - val_loss: 0.0824 - val_acc: 0.9303 - val_recall_4: 0.9247 - val_precision_4: 0.9310 - val_f1_score: 0.9322
# Epoch 2/100
# 950/950 [==============================] - 321s 338ms/step - loss: 0.0277 - acc: 0.9507 - recall_4: 0.9692 - precision_4: 0.9739 - f1_score: 0.9489 - val_loss: 0.0450 - val_acc: 0.9567 - val_recall_4: 0.9612 - val_precision_4: 0.9590 - val_f1_score: 0.9568
# Epoch 3/100
# 950/950 [==============================] - 321s 338ms/step - loss: 0.0236 - acc: 0.9539 - recall_4: 0.9739 - precision_4: 0.9781 - f1_score: 0.9537 - val_loss: 0.0525 - val_acc: 0.9519 - val_recall_4: 0.9635 - val_precision_4: 0.9399 - val_f1_score: 0.9487
# Epoch 4/100
# 950/950 [==============================] - 321s 338ms/step - loss: 0.0232 - acc: 0.9531 - recall_4: 0.9748 - precision_4: 0.9791 - f1_score: 0.9531 - val_loss: 0.0593 - val_acc: 0.9471 - val_recall_4: 0.9269 - val_precision_4: 0.9442 - val_f1_score: 0.9463
# Epoch 5/100
# 950/950 [==============================] - 321s 338ms/step - loss: 0.0161 - acc: 0.9613 - recall_4: 0.9838 - precision_4: 0.9854 - f1_score: 0.9595 - val_loss: 0.0699 - val_acc: 0.9351 - val_recall_4: 0.9384 - val_precision_4: 0.9427 - val_f1_score: 0.9380
# Epoch 16/100
# 950/950 [==============================] - 321s 338ms/step - loss: 0.0126 - acc: 0.9666 - recall_4: 0.9869 - precision_4: 0.9886 - f1_score: 0.9645 - val_loss: 0.1337 - val_acc: 0.9014 - val_recall_4: 0.8995 - val_precision_4: 0.9016 - val_f1_score: 0.8998
# Epoch 17/100
# 950/950 [==============================] - 321s 338ms/step - loss: 0.0150 - acc: 0.9646 - recall_4: 0.9841 - precision_4: 0.9868 - f1_score: 0.9613 - val_loss: 0.0533 - val_acc: 0.9447 - val_recall_4: 0.9543 - val_precision_4: 0.9457 - val_f1_score: 0.9428
# Epoch 18/100
# 950/950 [==============================] - ETA: 0s - loss: 0.0114 - acc: 0.9650 - recall_4: 0.9878 - precision_4: 0.9894 - f1_score: 0.9668Restoring model weights from the end of the best epoch.
# 950/950 [==============================] - 321s 338ms/step - loss: 0.0114 - acc: 0.9650 - recall_4: 0.9878 - precision_4: 0.9894 - f1_score: 0.9668 - val_loss: 0.0694 - val_acc: 0.9303 - val_recall_4: 0.9384 - val_precision_4: 0.9448 - val_f1_score: 0.9276
# Epoch 00018: early stopping

# %%
# model.compile(
#     loss="binary_crossentropy",
#     optimizer=Adam(lr=0.0005),
#     metrics=[
#         "acc",
#         keras.metrics.Recall(),
#         keras.metrics.Precision(),
#         tfa.metrics.F1Score(num_classes=NUM_CLASSES, average="micro"),
#     ],
# )

# %%
# history = model.fit(
#     ds_train,
#     validation_data=ds_valid,
#     epochs=100,
#     steps_per_epoch=(train.shape[0] * 0.93) // BATCH_SIZE,
#     validation_steps=(valid.shape[0] * 0.07) // BATCH_SIZE,
#     verbose=1,
#     use_multiprocessing=True,
#     callbacks=callbacks,
# )

# %%
def plot_curves(model, loss=False):
    df = pd.DataFrame(model.history)
    if loss:
        plt.figure(figsize=(12, 6))
        plt.title("loss")
        plt.plot(df.iloc[:, 0], label="loss")
        plt.plot(df.iloc[:, 5], label="val_loss")
        plt.legend()
        plt.show()
    else:
        plt.figure(figsize=(12, 20))
        plt.subplot(4, 1, 1)
        plt.title("accuracy")
        plt.plot(df.iloc[:, 1], label="accuracy")
        plt.plot(df.iloc[:, 6], label="val_accuracy")
        plt.legend()

        plt.subplot(4, 1, 2)
        plt.title("recall")
        plt.plot(df.iloc[:, 2], label="recall")
        plt.plot(df.iloc[:, 7], label="val_recall")
        plt.legend()

        plt.subplot(4, 1, 3)
        plt.title("precision")
        plt.plot(df.iloc[:, 3], label="precision")
        plt.plot(df.iloc[:, 8], label="val_precision")
        plt.legend()

        plt.subplot(4, 1, 4)
        plt.title("f1")
        plt.plot(df.iloc[:, 4], label="f1")
        plt.plot(df.iloc[:, 9], label="val_f1")
        plt.legend()
        plt.show();

# %%
plot_curves(history, loss=False)

# %%
# model = keras.models.load_model("/app/_data/models/new/bond_box_999_200.h5")

# %%
def parse_all(file_path):
    img = tf.io.read_file(TRAIN_IMG_PATH+file_path)
    img = tf.image.decode_jpeg(img, channels=3)
    return img
def predict_new(path, model):
    img = parse_all(path)
    img = tf.expand_dims(img,axis = 0)
    pred = model.predict(img)
    return pred_to_labels(pred[0])
# def parse_all(file_path):
#     img = tf.io.read_file(TRAIN_IMG_PATH + file_path)
#     img = tf.image.decode_jpeg(img, channels=3)
#     img = tf.image.convert_image_dtype(img, tf.float32)
#     img = tf.image.resize(
#         img,
#         (380, 380),
#     )
#     img = tf.image.convert_image_dtype(img, tf.uint8)
#     return img


# def predict_new(path, model):
#     img = parse_all(path)
#     img = tf.expand_dims(img, axis=0)
#     pred = model.predict(img)
#     return pred[0]

# %%
# a = predict_new('9eb93fe282326266.jpg', model)

# %%
df_sub = pd.DataFrame(columns=['image','labels'])
for img_name in os.listdir(TRAIN_IMG_PATH):
    pred = predict_new(img_name, model)

    df_sub = df_sub.append( {'image': img_name, 'labels': pred}, ignore_index = True )

print(df_sub.head())
# df_boxes = pd.DataFrame()
# for img_name in os.listdir(PATH + "images/"):
#     if img_name[-4:] == ".jpg":
#         pred = predict_new(img_name, model)
#         df_boxes.loc[img_name, "x_min"] = pred[0]
#         df_boxes.loc[img_name, "y_min"] = pred[1]
#         df_boxes.loc[img_name, "x_max"] = pred[2]
#         df_boxes.loc[imga_name, "y_max"] = pred[3]
# Out:
#                   image                   labels
# 0  bfc6d90f402f4c34.jpg  frog_eye_leaf_spot scab
# 1  9eb93fe282326266.jpg           powdery_mildew
# 2  f4cb3a8f41b413e4.jpg       frog_eye_leaf_spot
# 3  98322eab16bef2c1.jpg                     rust
# 4  dad5d6250cae80b7.jpg                  complex

# %%
# df_boxes.to_csv(PATH + "df_boxes_20.csv")

# %%
df_sub = df_sub.merge(
    labels[["image", "labels"]],
    on="image",
    how="left",
    suffixes=("_pred", "_true"),
)

# %%
df_sub.to_csv("/app/sandbox/wrong_predictions/eff4_ns_cr_kf_5.csv")

# %%
# df_boxes

# %%
df_sub[df_sub["labels_pred"] == ""]["labels_true"].value_counts()
# Out:
# scab                                       168
# healthy                                     93
# complex                                     53
# frog_eye_leaf_spot                          19
# scab frog_eye_leaf_spot                     17
# scab                                         9
# rust                                         2
# scab frog_eye_leaf_spot                      1
# rust frog_eye_leaf_spot                      1
# scab frog_eye_leaf_spot powdery_mildew       1
# powdery_mildew                               1
# frog_eye_leaf_spot complex                   1
# Name: labels_true, dtype: int64

# %%
PATH+'images/'+
# Out:
# '/app/_data/images/'

# %%
df_sub[df_sub["labels_pred"] != df_sub["labels_true"]]["labels_true"].value_counts()
# Out:
# scab frog_eye_leaf_spot            682
# complex                            438
# scab frog_eye_leaf_spot complex    200
# frog_eye_leaf_spot complex         165
# scab                               124
# rust frog_eye_leaf_spot            118
# rust complex                        91
# powdery_mildew complex              87
# rust                                74
# frog_eye_leaf_spot                  71
# healthy                             19
# powdery_mildew                       7
# Name: labels_true, dtype: int64
