# %%
import os

import numpy as np
import pandas as pd
from IPython.core.interactiveshell import InteractiveShell

InteractiveShell.ast_node_interactivity = "all"
import warnings

warnings.filterwarnings("ignore")

import matplotlib.pyplot as plt

# %matplotlib inline

import sklearn
import tensorflow as tf
import tensorflow_addons as tfa
from PIL import Image

from sklearn.model_selection import (
    StratifiedKFold,
    StratifiedShuffleSplit,
    train_test_split,
)
from tensorflow import keras
from tensorflow.keras.applications.efficientnet import EfficientNetB4, EfficientNetB7
from tensorflow.keras.layers import (
    AveragePooling2D,
    AvgPool2D,
    Conv2D,
    Dense,
    Flatten,
    GlobalAveragePooling2D,
    MaxPooling2D,
)
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tqdm import notebook, tqdm

# %%
PATH = "/app/_data/"
BATCH_SIZE = 16
SEED = 1488
IMAGE_SIZE = 380
NUM_CLASSES = 6
TRAIN_IMG_PATH = "/app/_data/cropped_all_v1/"
TEST_IMG_PATH = "/app/_data/test_images/"

# %%
labels = pd.read_csv('../_data/df_csv/labels_21_20_plus_test20_without_complex.csv', index_col=[0])
feature_columns = ['complex', 'frog_eye_leaf_spot', 'healthy', 'powdery_mildew', 'rust', 'scab']

# %% [markdown]
# ### StratifiedShuffleSplit

# %% [markdown]
#  - v1 - labels_long_1 0.812+scab
#  - v2 - labels_21_20 - 0,78 + scab
#  - v3 - labels+all_wrong*4 0.574 +scab
#  - v3 - labels + upsampling

# %%
train, valid = train_test_split(labels, train_size=0.8, random_state=SEED)

# %%
train["labels"].value_counts(normalize=True)
# Out:
# scab                               0.267857
# healthy                            0.253213
# frog_eye_leaf_spot                 0.157007
# rust                               0.119933
# complex                            0.077731
# powdery_mildew                     0.058020
# scab frog_eye_leaf_spot            0.033243
# scab frog_eye_leaf_spot complex    0.010381
# frog_eye_leaf_spot complex         0.007662
# rust frog_eye_leaf_spot            0.005746
# rust complex                       0.004881
# powdery_mildew complex             0.004325
# Name: labels, dtype: float64

# %%
valid["labels"].value_counts(normalize=True)
# Out:
# scab                               0.263470
# healthy                            0.252595
# frog_eye_leaf_spot                 0.156698
# rust                               0.121849
# complex                            0.078843
# powdery_mildew                     0.059565
# scab frog_eye_leaf_spot            0.035591
# frog_eye_leaf_spot complex         0.010133
# scab frog_eye_leaf_spot complex    0.007909
# rust frog_eye_leaf_spot            0.006179
# powdery_mildew complex             0.004202
# rust complex                       0.002966
# Name: labels, dtype: float64

# %%
def pred_to_labels(pred, thresh=0.5, labels=feature_columns):
    pred = [labels[i] for i in range(len(labels)) if pred[i] > thresh]
    pred = " ".join(pred)
    return pred

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
data_augmentation = keras.Sequential(
    [
        keras.layers.experimental.preprocessing.RandomFlip(
            "horizontal_and_vertical", seed=SEED
        ),
        keras.layers.experimental.preprocessing.RandomRotation(0.5, seed=SEED),
        keras.layers.experimental.preprocessing.RandomZoom(0.1, 0.1, seed=SEED),
        keras.layers.experimental.preprocessing.RandomContrast(factor=0.3, seed=SEED),
        keras.layers.experimental.preprocessing.RandomTranslation(
            height_factor=0.1, width_factor=0.1, seed=SEED
        ),
    ]
)

# %%
# df_crop1 = pd.read_csv(PATH+'df_boxes.csv')
# df_crop2 = pd.read_csv(PATH+'df_boxes_20.csv')
# df_crop1.columns = ['image', 'x_min', 'y_min', 'x_max', 'y_max']
# df_crop2.columns = ['image', 'x_min', 'y_min', 'x_max', 'y_max']
# df_crop = pd.concat([df_crop1, df_crop2], axis=0, ignore_index=True)
# def write_np(file_path):
#     img = tf.io.read_file(PATH + 'train_images/'+ file_path)
#     img = tf.image.decode_jpeg(img, channels=3)
#     coord = df_crop[df_crop["image"] == file_path][['x_min', 'y_min', 'x_max', 'y_max']].values[0]
#     orig_hight = img.shape[0]
#     orig_width = img.shape[1]
#     x_min = coord[0]
#     y_min = coord[1]
#     x_max = coord[2]
#     y_max = coord[3]
#     cropped_image = img.numpy()[np.int(y_min*orig_hight):np.int(y_max*orig_hight),np.int(x_min*orig_width):np.int(x_max*orig_width)]
#     img = tf.image.resize(cropped_image, (600, 600))
#     img = tf.cast(img, dtype='uint8')
#     img = Image.fromarray(img.numpy())
#     img.save(PATH + 'cropped_all_600_v1/'+file_path)
# #     return img
# # labels_21_20['image'].apply(write_np)
# all_imgs = os.listdir(PATH + 'train_images/')
# for i in tqdm(range(len(all_imgs))):
#     if all_imgs[i] in df_crop["image"].values:
#          write_np(all_imgs[i])

# %%
len(os.listdir(TRAIN_IMG_PATH))
# Out:
# 21221

# %%
# from 380 uint8
def parse_image(file_path):
    img = tf.io.read_file(TRAIN_IMG_PATH + file_path)
    img = tf.image.decode_jpeg(img, channels=3)
    return img

# %%
plt.imshow(parse_image(os.listdir(PATH + "cropped_all_600_v1/")[5255]))

# %%
def prepare_dataset(df, augmentation=False):
    dataset = tf.data.Dataset.from_tensor_slices(
        (df["image"].values, df[feature_columns].astype("uint8").values)
    )
    dataset = dataset.map(lambda x, y: (parse_image(x), y))
    dataset = dataset.batch(BATCH_SIZE)

    if augmentation:
        dataset = dataset.map(
            lambda x, y: (data_augmentation(x, training=True), y),
            num_parallel_calls=AUTOTUNE,
        )
    dataset = dataset.repeat().prefetch(buffer_size=AUTOTUNE)
    return dataset

# %%
ds_train = prepare_dataset(train, augmentation=True)
ds_valid = prepare_dataset(valid)

# %%
for a, b in ds_train.take(1):
    print(a[0].dtype, b.dtype)
    print(a[0].shape, b.shape)
# Out:
# <dtype: 'uint8'> <dtype: 'uint8'>
# (380, 380, 3) (16, 6)

# %%
plt.imshow(a[0])

# %%
def parse_test_image(img_name):
    img = tf.io.read_file(img_name)
    img = tf.image.decode_jpeg(img, channels=3)
    img = tf.image.convert_image_dtype(img, tf.float32)
    img = tf.image.resize(
        img,
        IMAGE_SIZE,
    )
    img = tf.image.convert_image_dtype(img, tf.uint8)
    return img
def predict_new(path, model):
    img = parse_test_image(path)
    img = tf.expand_dims(img, axis=0)
    pred = model.predict(img)
    return pred_to_labels(pred[0])

# %%
policy = keras.mixed_precision.experimental.Policy('mixed_float16')
keras.mixed_precision.experimental.set_policy(policy)
# Out:
# INFO:tensorflow:Mixed precision compatibility check (mixed_float16): OK
# Your GPU will likely run quickly with dtype policy mixed_float16 as it has compute capability of at least 7.0. Your GPU: Quadro RTX 5000, compute capability 7.5

# %%
callbacks = [
    keras.callbacks.EarlyStopping(
        monitor="f1_score",
        patience=10,
        restore_best_weights=True,
        verbose=1,
        mode="max",
    ),
    keras.callbacks.ModelCheckpoint(
        "/app/_data/models/new/eff4_ns_cropped_5_all.h5",
        monitor="f1_score",
        verbose=1,
        save_best_only=True,
        save_weights_only=False,
        mode="max",
        save_freq="epoch",
    ),
    keras.callbacks.ReduceLROnPlateau(
        monitor="f1_score",
        factor=0.5,
        patience=6,
        verbose=1,
        mode="max",
        min_delta=1e-4,
        min_lr=0.00000001,
    ),
]

# %%
# base_model = keras.applications.EfficientNetB4(weights=None, include_top=False)
# base_model.load_weights('/app/_data/models/efficientnet-b4_noisy-student_notop.h5', by_name=True, skip_mismatch = True)

# %%
inputs = keras.Input(shape=(IMAGE_SIZE, IMAGE_SIZE,3))
base_model = keras.applications.EfficientNetB4(weights=None, include_top=False)
base_model.load_weights(
    "/app/_data/models/efficientnet-b4_noisy-student_notop.h5",
    by_name=True,
    skip_mismatch=True,
)
x = base_model(inputs)
x = keras.layers.GlobalAveragePooling2D(name="avg_pool")(x)
x = keras.layers.Flatten(name="flatten")(x)
outputs = keras.layers.Dense(NUM_CLASSES, activation="sigmoid")(x)
model = keras.Model(inputs=inputs, outputs=outputs)

# %%
model.compile(
    loss="binary_crossentropy",
    optimizer=Adam(lr=0.0005),
    metrics=[
        "acc",
        keras.metrics.Recall(),
        keras.metrics.Precision(),
        tfa.metrics.F1Score(num_classes=NUM_CLASSES, average="micro"),
    ],
)

# %%
labels.shape[0] // BATCH_SIZE
# Out:
# 1264

# %%
history = model.fit(
    ds_train,
    validation_data=ds_valid,
    epochs=100,
    steps_per_epoch=(train.shape[0] * 0.8) // BATCH_SIZE,
    validation_steps=(valid.shape[0] * 0.2) // BATCH_SIZE,
    verbose=1,
    use_multiprocessing=True,
    callbacks=callbacks,
)
# Out:
# Epoch 1/100
# 1264/1264 [==============================] - ETA: 0s - loss: 0.1418 - acc: 0.8465 - recall: 0.8077 - precision: 0.8698 - f1_score: 0.8398
# Epoch 00001: f1_score improved from -inf to 0.83977, saving model to /app/_data/models/new/eff4_ns_cropped_5_all.h5
# 1264/1264 [==============================] - 422s 334ms/step - loss: 0.1418 - acc: 0.8465 - recall: 0.8077 - precision: 0.8698 - f1_score: 0.8398
# Epoch 2/100
# 1264/1264 [==============================] - ETA: 0s - loss: 0.1094 - acc: 0.8862 - recall: 0.8587 - precision: 0.8986 - f1_score: 0.8762
# Epoch 00002: f1_score improved from 0.83977 to 0.87618, saving model to /app/_data/models/new/eff4_ns_cropped_5_all.h5
# 1264/1264 [==============================] - 423s 335ms/step - loss: 0.1094 - acc: 0.8862 - recall: 0.8587 - precision: 0.8986 - f1_score: 0.8762
# Epoch 3/100
# 1264/1264 [==============================] - ETA: 0s - loss: 0.0991 - acc: 0.8970 - recall: 0.8720 - precision: 0.9087 - f1_score: 0.8869
# Epoch 00003: f1_score improved from 0.87618 to 0.88693, saving model to /app/_data/models/new/eff4_ns_cropped_5_all.h5
# 1264/1264 [==============================] - 427s 338ms/step - loss: 0.0991 - acc: 0.8970 - recall: 0.8720 - precision: 0.9087 - f1_score: 0.8869
# Epoch 4/100
# 1264/1264 [==============================] - ETA: 0s - loss: 0.
# 1264/1264 [==============================] - 426s 337ms/step - loss: 5.9549e-04 - acc: 0.9946 - recall: 0.9995 - precision: 0.9994 - f1_score: 0.9953
# Epoch 96/100
# 1264/1264 [==============================] - ETA: 0s - loss: 7.3100e-04 - acc: 0.9935 - recall: 0.9994 - precision: 0.9991 - f1_score: 0.9936
# Epoch 00096: f1_score did not improve from 0.99534
# 1264/1264 [==============================] - 425s 336ms/step - loss: 7.3100e-04 - acc: 0.9935 - recall: 0.9994 - precision: 0.9991 - f1_score: 0.9936
# Epoch 97/100
# 1264/1264 [==============================] - ETA: 0s - loss: 6.6393e-04 - acc: 0.9945 - recall: 0.9996 - precision: 0.9995 - f1_score: 0.9942
# Epoch 00097: f1_score did not improve from 0.99534
# 1264/1264 [==============================] - 425s 336ms/step - loss: 6.6393e-04 - acc: 0.9945 - recall: 0.9996 - precision: 0.9995 - f1_score: 0.9942
# Epoch 98/100
# 1264/1264 [==============================] - ETA: 0s - loss: 7.1427e-04 - acc: 0.9920 - recall: 0.9992 - precision: 0.9992 - f1_score: 0.9926
# Epoch 00098: f1_score did not improve from 0.99534
# 1264/1264 [==============================] - 425s 336ms/step - loss: 7.1427e-04 - acc: 0.9920 - recall: 0.9992 - precision: 0.9992 - f1_score: 0.9926
# Epoch 99/100
# 1264/1264 [==============================] - ETA: 0s - loss: 0.0011 - acc: 0.9931 - recall: 0.9989 - precision: 0.9992 - f1_score: 0.9932
# Epoch 00099: f1_score did not improve from 0.99534
# 1264/1264 [==============================] - 425s 336ms/step - loss: 0.0011 - acc: 0.9931 - recall: 0.9989 - precision: 0.9992 - f1_score: 0.9932
# Epoch 100/100
# 1264/1264 [==============================] - ETA: 0s - loss: 7.4182e-04 - acc: 0.9940 - recall: 0.9994 - precision: 0.9994 - f1_score: 0.9939
# Epoch 00100: f1_score did not improve from 0.99534
# 1264/1264 [==============================] - 425s 336ms/step - loss: 7.4182e-04 - acc: 0.9940 - recall: 0.9994 - precision: 0.9994 - f1_score: 0.9939

# %%
def plot_curves(model, loss=False):
    df = pd.DataFrame(model.history)
    if loss:
        plt.figure(figsize=(12, 6))
        plt.title("loss")
        plt.plot(df.iloc[:, 0], label="loss")
        plt.plot(df.iloc[:, 5], label="val_loss")
        plt.legend()
        plt.show()
    else:
        plt.figure(figsize=(12, 20))
        plt.subplot(4, 1, 1)
        plt.title("accuracy")
        plt.plot(df.iloc[:, 1], label="accuracy")
        plt.plot(df.iloc[:, 6], label="val_accuracy")
        plt.legend()

        plt.subplot(4, 1, 2)
        plt.title("recall")
        plt.plot(df.iloc[:, 2], label="recall")
        plt.plot(df.iloc[:, 7], label="val_recall")
        plt.legend()

        plt.subplot(4, 1, 3)
        plt.title("precision")
        plt.plot(df.iloc[:, 3], label="precision")
        plt.plot(df.iloc[:, 8], label="val_precision")
        plt.legend()

        plt.subplot(4, 1, 4)
        plt.title("f1")
        plt.plot(df.iloc[:, 4], label="f1")
        plt.plot(df.iloc[:, 9], label="val_f1")
        plt.legend()
        plt.show();

# %%
plot_curves(history, loss=True)

# %%
model = keras.models.load_model("/app/_data/models/new/bond_box_999_200.h5")

# %%
def parse_all(file_path):
    img = tf.io.read_file(TRAIN_IMG_PATH+file_path)
    img = tf.image.decode_jpeg(img, channels=3)
    return img
def predict_new(path, model):
    img = parse_all(path)
    img = tf.expand_dims(img,axis = 0)
    pred = model.predict(img)
    return pred_to_labels(pred[0])
# def parse_all(file_path):
#     img = tf.io.read_file(TRAIN_IMG_PATH + file_path)
#     img = tf.image.decode_jpeg(img, channels=3)
#     img = tf.image.convert_image_dtype(img, tf.float32)
#     img = tf.image.resize(
#         img,
#         (380, 380),
#     )
#     img = tf.image.convert_image_dtype(img, tf.uint8)
#     return img


# def predict_new(path, model):
#     img = parse_all(path)
#     img = tf.expand_dims(img, axis=0)
#     pred = model.predict(img)
#     return pred[0]

# %%
# a = predict_new('9eb93fe282326266.jpg', model)

# %%
df_sub = pd.DataFrame(columns=['image','labels'])
for img_name in os.listdir(TRAIN_IMG_PATH):
    pred = predict_new(img_name, model)

    df_sub = df_sub.append( {'image': img_name, 'labels': pred}, ignore_index = True )

print(df_sub.head())
# df_boxes = pd.DataFrame()
# for img_name in os.listdir(PATH + "images/"):
#     if img_name[-4:] == ".jpg":
#         pred = predict_new(img_name, model)
#         df_boxes.loc[img_name, "x_min"] = pred[0]
#         df_boxes.loc[img_name, "y_min"] = pred[1]
#         df_boxes.loc[img_name, "x_max"] = pred[2]
#         df_boxes.loc[imga_name, "y_max"] = pred[3]
# Out:
#                   image                   labels
# 0  bfc6d90f402f4c34.jpg  frog_eye_leaf_spot scab
# 1  9eb93fe282326266.jpg           powdery_mildew
# 2  f4cb3a8f41b413e4.jpg       frog_eye_leaf_spot
# 3  98322eab16bef2c1.jpg                     rust
# 4  dad5d6250cae80b7.jpg                  complex

# %%
# df_boxes.to_csv(PATH + "df_boxes_20.csv")

# %%
df_sub = df_sub.merge(
    labels_21_20[["image", "labels"]],
    on="image",
    how="left",
    suffixes=("_pred", "_true"),
)

# %%
df_sub.to_csv("/app/sandbox/wrong_predictions/eff4/eff4_ns_cropped_2.csv")

# %%
# df_boxes

# %%
df_sub[df_sub["labels_pred"] == ""]["labels_true"].value_counts()
# Out:
# complex                    22
# scab                       10
# rust                        7
# frog_eye_leaf_spot          5
# scab frog_eye_leaf_spot     1
# rust frog_eye_leaf_spot     1
# powdery_mildew complex      1
# powdery_mildew              1
# healthy                     1
# Name: labels_true, dtype: int64

# %%
PATH+'images/'+
# Out:
# '/app/_data/images/'

# %%
df_sub[df_sub["labels_pred"] != df_sub["labels_true"]]["labels_true"].value_counts()
# Out:
# scab frog_eye_leaf_spot            682
# complex                            438
# scab frog_eye_leaf_spot complex    200
# frog_eye_leaf_spot complex         165
# scab                               124
# rust frog_eye_leaf_spot            118
# rust complex                        91
# powdery_mildew complex              87
# rust                                74
# frog_eye_leaf_spot                  71
# healthy                             19
# powdery_mildew                       7
# Name: labels_true, dtype: int64
