# %%
import kaggle
# Out:
# Warning: Your Kaggle API key is readable by other users on this system! To fix this, you can run 'chmod 600 /app/kaggle.json'

# %%
! kaggle datasets init -p /app/_data/models/final/Eff5FullTrain/
# Out:
# Warning: Your Kaggle API key is readable by other users on this system! To fix this, you can run 'chmod 600 /app/kaggle.json'
# Data package template written to: /app/_data/models/final/Eff5FullTrain/dataset-metadata.json

# %%
! kaggle datasets create -p /app/_data/models/final/Eff5FullTrain/
# Out:
# Warning: Your Kaggle API key is readable by other users on this system! To fix this, you can run 'chmod 600 /app/kaggle.json'
# Starting upload for file Eff5FullTrain_1.h5
# 100%|█████████████████████████████████████████| 327M/327M [07:51<00:00, 727kB/s]
# Upload successful: Eff5FullTrain_1.h5 (327MB)
# Starting upload for file Eff5FullTrain_3.h5
# 100%|█████████████████████████████████████████| 327M/327M [07:56<00:00, 720kB/s]
# Upload successful: Eff5FullTrain_3.h5 (327MB)
# Starting upload for file Eff5FullTrain_5.h5
# 100%|█████████████████████████████████████████| 327M/327M [08:07<00:00, 704kB/s]
# Upload successful: Eff5FullTrain_5.h5 (327MB)
# Starting upload for file Eff5FullTrain_4.h5
# 100%|█████████████████████████████████████████| 327M/327M [07:57<00:00, 718kB/s]
# Upload successful: Eff5FullTrain_4.h5 (327MB)
# Starting upload for file Eff5FullTrain_2.h5
# 100%|█████████████████████████████████████████| 327M/327M [07:52<00:00, 726kB/s]
# Upload successful: Eff5FullTrain_2.h5 (327MB)
# Skipping folder: .ipynb_checkpoints; use '--dir-mode' to upload folders
# Your private Dataset is being created. Please check progress at https://www.kaggle.com/nataliayurasova/Eff5FullTrain

# %%
! pip install albumentations
import albumentations
# Out:
# Requirement already satisfied: albumentations in /usr/local/lib/python3.8/dist-packages (0.5.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.8/dist-packages (from albumentations) (1.4.1)
# Requirement already satisfied: scikit-image>=0.16.1 in /usr/local/lib/python3.8/dist-packages (from albumentations) (0.18.1)
# Requirement already satisfied: opencv-python-headless>=4.1.1 in /usr/local/lib/python3.8/dist-packages (from albumentations) (4.5.2.52)
# Requirement already satisfied: imgaug>=0.4.0 in /usr/local/lib/python3.8/dist-packages (from albumentations) (0.4.0)
# Requirement already satisfied: numpy>=1.11.1 in /usr/local/lib/python3.8/dist-packages (from albumentations) (1.17.3)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.8/dist-packages (from albumentations) (5.3.1)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.8/dist-packages (from imgaug>=0.4.0->albumentations) (8.2.0)
# Requirement already satisfied: Shapely in /usr/local/lib/python3.8/dist-packages (from imgaug>=0.4.0->albumentations) (1.7.1)
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from imgaug>=0.4.0->albumentations) (1.15.0)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.8/dist-packages (from imgaug>=0.4.0->albumentations) (4.5.2.52)
# Requirement already satisfied: imageio in /usr/local/lib/python3.8/dist-packages (from imgaug>=0.4.0->albumentations) (2.9.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.8/dist-packages (from imgaug>=0.4.0->albumentations) (3.4.1)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.8/dist-packages (from scikit-image>=0.16.1->albumentations) (2021.4.8)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.8/dist-packages (from scikit-image>=0.16.1->albumentations) (1.1.1)
# Requirement already satisfied: networkx>=2.0 in /usr/local/lib/python3.8/dist-packages (from scikit-image>=0.16.1->albumentations) (2.5.1)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib->imgaug>=0.4.0->albumentations) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.8/dist-packages (from matplotlib->imgaug>=0.4.0->albumentations) (2.8.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib->imgaug>=0.4.0->albumentations) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.8/dist-packages (from matplotlib->imgaug>=0.4.0->albumentations) (0.10.0)
# Requirement already satisfied: decorator<5,>=4.3 in /usr/local/lib/python3.8/dist-packages (from networkx>=2.0->scikit-image>=0.16.1->albumentations) (4.4.2)
# WARNING: You are using pip version 21.0.1; however, version 21.1.1 is available.
# You should consider upgrading via the '/usr/bin/python -m pip install --upgrade pip' command.

# %%
import os

import numpy as np
import pandas as pd
from IPython.core.interactiveshell import InteractiveShell

InteractiveShell.ast_node_interactivity = "all"
import warnings

warnings.filterwarnings("ignore")

import matplotlib.pyplot as plt
import sklearn
import tensorflow as tf
import tensorflow_addons as tfa
from PIL import Image
from sklearn.model_selection import (
    StratifiedKFold,
    StratifiedShuffleSplit,
    train_test_split,
)
from tensorflow import keras
from tensorflow.keras.applications.efficientnet import EfficientNetB4, EfficientNetB7
from tensorflow.keras.layers import (
    AveragePooling2D,
    AvgPool2D,
    Conv2D,
    Dense,
    Flatten,
    GlobalAveragePooling2D,
    MaxPooling2D,
)
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tqdm import notebook, tqdm

# %matplotlib inline

# %%
PATH = "/app/_data/"
BATCH_SIZE = 26
SEED = 42
IMAGE_SIZE = 456
NUM_CLASSES = 6
TRAIN_IMG_PATH = "/app/_data/456_npy/"
TEST_IMG_PATH = "/app/_data/test_images/"
feature_columns = [
    "complex",
    "frog_eye_leaf_spot",
    "healthy",
    "powdery_mildew",
    "rust",
    "scab",
]
wrong = [
    "ead085dfac287263.jpg",
    "95276ccd226ad933.jpg",
    "da8770e819d2696d.jpg",
    "cd3a1d64e6806eb5.jpg",
    "ccec54723ff91860.jpg",
]

# %%
df_labels = pd.read_csv("/app/_data/df_csv/labels_21_20.csv", index_col=[0])
df_labels = df_labels.query("image not in @wrong").reset_index(drop=True)
df_labels["image"] = df_labels["image"].str.replace(".jpg", ".npy")

# %%
df_labels = df_labels.sample(frac=1, random_state=SEED)

# %%
df_labels.shape
# Out:
# (20225, 8)

# %%
# for 380*380
transform = albumentations.Compose(
    [
        albumentations.CLAHE(p=0.1, clip_limit=(1, 2), tile_grid_size=(8, 8)),
        albumentations.OneOf(
            [
                albumentations.MotionBlur((3, 3)),
                albumentations.MedianBlur(blur_limit=3),
                albumentations.GaussianBlur(blur_limit=(3, 3), sigma_limit=0),
                albumentations.Blur(blur_limit=(3, 3)),
            ],
            p=0.2,
        ),
        albumentations.OneOf(
            [
                albumentations.GaussNoise(var_limit=[10, 50], mean=1),
                albumentations.ISONoise(intensity=(0.1, 1), color_shift=(0.01, 0.05)),
                albumentations.ImageCompression(
                    quality_lower=70, quality_upper=100, compression_type=1
                ),
                albumentations.MultiplicativeNoise(
                    multiplier=(0.95, 1.05), per_channel=True, elementwise=True
                ),
                albumentations.Downscale(
                    scale_min=0.6, scale_max=0.99, interpolation=4
                ),
            ],
            p=0.5,
        ),
        albumentations.OneOf(
            [
                albumentations.HueSaturationValue(
                    hue_shift_limit=(-7, 7),
                    sat_shift_limit=(-10, 10),
                    val_shift_limit=(-10, 10),
                ),
                albumentations.RandomBrightnessContrast(
                    brightness_limit=0.15,
                    contrast_limit=0.2,
                    brightness_by_max=True,
                ),
            ],
            p=0.5,
        ),
        albumentations.OneOf(
            [
                albumentations.OpticalDistortion(
                    distort_limit=0.05,
                    shift_limit=0.05,
                    border_mode=2,
                ),
                albumentations.ElasticTransform(
                    alpha=2.0,
                    sigma=50.0,
                    alpha_affine=10.0,
                    interpolation=0,
                    border_mode=2,
                ),
                albumentations.GridDistortion(
                    num_steps=5, distort_limit=0.3, interpolation=0, border_mode=2
                ),
            ],
            p=0.5,
        ),
        albumentations.OneOf(
            [
                albumentations.HorizontalFlip(),
                albumentations.VerticalFlip(),
            ],
            p=0.5,
        ),
        albumentations.OneOf(
            [
                albumentations.Rotate(
                    limit=(-180, 180), interpolation=0, border_mode=2
                ),
                albumentations.ShiftScaleRotate(
                    shift_limit=0.05,
                    scale_limit=0.05,
                    rotate_limit=180,
                    interpolation=0,
                    border_mode=2,
                ),
            ],
            p=0.5,
        ),
    ]
)

# %%
class Generator(keras.utils.Sequence):
    def __init__(
        self,
        df,
        images_src_dir,
        batch_size,
        target_image_size,
        shuffle=False,
        augment=True,
        crop=False,
        resize=False,
        normalize=False,
    ):
        self.shuffle = shuffle
        self.batch_size = BATCH_SIZE
        self.df = df
        self.images_dir = images_src_dir
        self.target_image_size = (IMAGE_SIZE, IMAGE_SIZE)
        self.augment = augment
        self.crop = crop
        self.resize = resize
        self.normalize = normalize
        # create label index map
        self.labels = self._read_labels()
        self.n_samples = self.df.shape[0]
        self.n_batches = self.n_samples // self.batch_size
        # shuffle data, also repeated after each epoch if needed
        if self.shuffle:
            np.random.shuffle(self.labels)

    def _read_labels(self):
        """
        Returns list images mapping to 1-hot label
        """

        # label indexes
        label_ixs = self.df[feature_columns].values
        image_ixs = self.df["image"].values
        labels = []

        for i in range(len(image_ixs)):
            labels.append([image_ixs[i], label_ixs[i]])
        return labels

    def __len__(self):
        """
        Length in batches
        """
        return self.n_batches

    def __getitem__(self, b_ix):
        """
        Produce batch, by batch index
        """

        assert b_ix < self.n_batches

        b_X = np.zeros(
            (self.batch_size, self.target_image_size[0], self.target_image_size[1], 3),
            dtype=np.uint8,
        )

        b_Y = np.zeros(
            (self.batch_size, self.df[feature_columns].shape[1]),
            dtype=np.uint8,
        )

        for i in range(self.batch_size):
            b_X[i], b_Y[i] = self.get_one(
                i + self.batch_size * b_ix,
            )

        return (b_X, b_Y)

    def get_one(self, one_ix):
        """
        Get single item by absolute index
        """
        id = self.labels[one_ix][0]
        src_file = self.images_dir + id

        # read file
        x = np.load(src_file)
        if self.crop:
            coord = self.df[self.df["image"] == id][
                ["x_min", "y_min", "x_max", "y_max"]
            ].values[0]
            orig_hight = x.shape[0]
            orig_width = x.shape[1]
            x_min = coord[0]
            y_min = coord[1]
            x_max = coord[2]
            y_max = coord[3]
            x = x[
                np.int(y_min * orig_hight) : np.int(y_max * orig_hight),
                np.int(x_min * orig_width) : np.int(x_max * orig_width),
            ]

        y = self.labels[one_ix][1]

        # augment
        if self.augment:
            x = self._augment_image(x)

        # normalize (sample-wise)
        if self.normalize:
            x = x.astype(np.float32)
            x = x - np.mean(x, axis=(0, 1))
            x = x / np.std(x, axis=(0, 1))
        return x.astype(np.uint8), y

    def _augment_image(self, x):
        """
        Randomply augment image
        """

        x = transform(image=x)["image"]
        return x

    def on_epoch_end(self):
        if self.shuffle:
            np.random.shuffle(self.labels)

# %%
gen = Generator(
    df=df_labels.sample(100),
    images_src_dir=TRAIN_IMG_PATH,
    target_image_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    shuffle=False,
    augment=False,
    crop=False,
    resize=False,
)

# %%
gen.__len__()
# Out:
# 3

# %%
policy = keras.mixed_precision.experimental.Policy("mixed_float16")
keras.mixed_precision.experimental.set_policy(policy)
# Out:
# INFO:tensorflow:Mixed precision compatibility check (mixed_float16): OK
# Your GPU will likely run quickly with dtype policy mixed_float16 as it has compute capability of at least 7.0. Your GPU: NVIDIA GeForce RTX 3090, compute capability 8.6

# %%
def get_model():
    inputs = keras.Input(shape=(IMAGE_SIZE, IMAGE_SIZE, 3))
    base_model = keras.applications.EfficientNetB5(weights=None, include_top=False)
    base_model.load_weights(
        "/app/_data/models/efficientnet-b5_noisy-student_notop.h5",
        by_name=True,
        skip_mismatch=True,
    )
    x = base_model(inputs)
    x = keras.layers.GlobalAveragePooling2D(name="avg_pool")(x)
    x = keras.layers.Flatten(name="flatten")(x)
    outputs = keras.layers.Dense(NUM_CLASSES, activation="sigmoid")(x)
    model = keras.Model(inputs=inputs, outputs=outputs)
    model.compile(
        loss="binary_crossentropy",
        optimizer=Adam(lr=0.0005),
        metrics=[
            "acc",
            keras.metrics.Recall(),
            keras.metrics.Precision(),
            tfa.metrics.F1Score(num_classes=NUM_CLASSES, average="weighted"),
        ],
    )
    return model

# %%
# model = get_model()
# history = model.fit(
#     gen,
#     epochs=100,
#     steps_per_epoch=100 // BATCH_SIZE,
#     verbose=1,
#     workers=15,
# )

# %%
# BATCH_SIZE=56

# %%
skf = StratifiedKFold(n_splits=5, random_state=SEED, shuffle=True)

for i, (train_index, valid_index) in enumerate(
    skf.split(df_labels["image"], df_labels["labels"])
):
    if i>=1:
        train, valid = df_labels.loc[train_index], df_labels.loc[valid_index]
        model_name = "Eff5FullTrain_" + str(i + 1) + ".h5"
        log_dir = "logs_Eff5FullTrain_" + str(i + 1) + "/"
        print('\nIter # ', str(i+1), 'starting\n')
        callbacks = [
            keras.callbacks.EarlyStopping(
                monitor="val_f1_score",
                patience=11,
                restore_best_weights=True,
                verbose=1,
                mode="max",
            ),
            keras.callbacks.ModelCheckpoint(
                "/app/_data/models/final/eff5FullTrain/" + model_name,
                monitor="val_f1_score",
                verbose=1,
                save_best_only=True,
                save_weights_only=False,
                mode="max",
                save_freq="epoch",
            ),
            keras.callbacks.ReduceLROnPlateau(
                monitor="val_f1_score",
                factor=0.9,
                patience=8,
                verbose=1,
                mode="max",
                min_delta=1e-4,
                min_lr=0.00000001,
            ),
            keras.callbacks.TensorBoard(
                log_dir="/app/.tensorboard/" + log_dir, histogram_freq=0
            ),
            keras.callbacks.experimental.BackupAndRestore(
                "/app/_data/models/final/eff5FullTrain/backup/"
            ),
            keras.callbacks.TerminateOnNaN()
        ]

        gen_train = Generator(
            df=train,
            images_src_dir=TRAIN_IMG_PATH,
            target_image_size=IMAGE_SIZE,
            batch_size=BATCH_SIZE,
            shuffle=True,
            augment=True,
            crop=False,
            resize=False,
        )
        gen_valid = Generator(
            df=valid,
            images_src_dir=TRAIN_IMG_PATH,
            target_image_size=IMAGE_SIZE,
            batch_size=BATCH_SIZE,
            shuffle=False,
            augment=False,
            crop=False,
            resize=False,
        )
        #         print(model_name, log_dir, gen_train.__len__(), gen_valid.__len__())
        model = get_model()
        history = model.fit(
            gen_train,
            validation_data=gen_valid,
            epochs=100,
            steps_per_epoch=train.shape[0] // BATCH_SIZE,
            validation_steps=valid.shape[0] // BATCH_SIZE,
            verbose=1,
            workers=15,
            callbacks=callbacks,
        )
        tf.keras.backend.clear_session()
# Out:
# Iter #  2 starting
#
# Epoch 1/100
#   1/622 [..............................] - ETA: 0s - loss: 0.7368 - acc: 0.1154 - recall: 0.6296 - precision: 0.1735 - f1_score: 0.1420WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/summary_ops_v2.py:1277: stop (from tensorflow.python.eager.profiler) is deprecated and will be removed after 2020-07-01.
# Instructions for updating:
# use `tf.profiler.experimental.stop` instead.
# 622/622 [==============================] - ETA: 0s - loss: 0.1427 - acc: 0.8433 - recall: 0.8113 - precision: 0.8726 - f1_score: 0.8328
# Epoch 00001: val_f1_score improved from -inf to 0.88810, saving model to /app/_data/models/final/eff5FullTrain/Eff5FullTrain_2.h5
# 622/622 [==============================] - 277s 446ms/step - loss: 0.1427 - acc: 0.8433 - recall: 0.8113 - precision: 0.8726 - f1_score: 0.8328 - val_loss: 0.0925 - val_acc: 0.9052 - val_recall: 0.8954 - val_precision: 0.9002 - val_f1_score: 0.8881
# Epoch 2/100
# 622/622 [==============================] - ETA: 0s - loss: 0.1056 - acc: 0.8883 - recall: 0.8661 - precision: 0.9020 - f1_score: 0.8764
# Epoch 00002: val_f1_score did not improve from 0.88810
# 622/622 [==============================] - 277s 445ms/step - loss: 0.1056 - acc: 0.8883 - recall: 0.8661 - precision: 0.9020 - f1_score: 0.8764 - val_loss: 0.0908 - val_acc: 0.9002 - val_recall: 0.8624 - val_precision: 0.9303 - val_f1_score: 0.8869
# Epoch 3/100
# 622/622 [==============================] - ETA: 0s - loss: 0.0956 - acc: 0.8975 - recall: 0.8792 - precision: 0.9077 - f1_score: 0.8865
# Epoch 00003: val_f1_score improved from 0.88810 to 0.89431, saving model to /app/_data/models/final/eff5FullTrain/Eff5FullTrain_2.h5
# 622/622 [==============================] - 288s 463ms/step - loss: 0.0956 - acc: 0.8975 - recall: 0.8792 - precision: 0.9077 - f1_score: 0.8865 - val_loss: 0.0842 - val_acc: 0.9005 - val_recall: 0.9141 - val_precision: 0.9045 - val_f1_score: 0.8943
# Epoch 4/100
# 622/622 [==============================] - ETA: 0s - loss: 0.0889 - acc: 0.9011 - recall: 0.8885 - precision: 0.9106 - f1_score: 0.8898
# Epoch 00004: val_f1_score improved from 0.89431 to 0.89596, saving model to /app/_data/models/final/eff5FullTrain/Eff5FullTrain_2.h5
# 622/622 [==============================] - 285s 459ms/step - loss: 0.0889 - acc: 0.9011 - recall: 0.8885 - precision: 0.9106 - f1_score: 0.8898 - val_loss: 0.0902 - val_acc: 0.9112 - val_recall: 0.8783 - val_precision: 0.9260 - val_f1_score: 0.8960
# Epoch 5/100
# 622/622 [==============================] - ETA: 0s - loss: 0.0828 - acc: 0.9081 - recall: 0.8980 - precision: 0.9158 - f1_score: 0.8973
# Epoch 00005: val_f1_score improved from 0.89596 to 0.89997, saving model to /app/_data/models/final/eff5FullTrain/Eff5FullTrain_2.h5
# 622/622 [==============================] - 288s 462ms/step - loss: 0.0828 - acc: 0.9081 - recall: 0.8980 - precision: 0.9158 - f1_score: 0.8973 - val_loss: 0.0745 - val_acc: 0.9087 - val_recall: 0.9146 - val_precision: 0.9177 - val_f1_score: 0.9000
# Epoch 6/100
# 622/622 [==============================] - ETA: 0s - loss: 0.
100
# 622/622 [==============================] - ETA: 0s - loss: 0.0221 - acc: 0.9578 - recall: 0.9749 - precision: 0.9774 - f1_score: 0.9529
# Epoch 00032: val_f1_score did not improve from 0.90798
# 622/622 [==============================] - 286s 459ms/step - loss: 0.0221 - acc: 0.9578 - recall: 0.9749 - precision: 0.9774 - f1_score: 0.9529 - val_loss: 0.1385 - val_acc: 0.9094 - val_recall: 0.9022 - val_precision: 0.9212 - val_f1_score: 0.8969
# Epoch 33/100
# 622/622 [==============================] - ETA: 0s - loss: 0.0224 - acc: 0.9564 - recall: 0.9731 - precision: 0.9785 - f1_score: 0.9526Restoring model weights from the end of the best epoch.
#
# Epoch 00033: val_f1_score did not improve from 0.90798
# 622/622 [==============================] - 285s 458ms/step - loss: 0.0224 - acc: 0.9564 - recall: 0.9731 - precision: 0.9785 - f1_score: 0.9526 - val_loss: 0.1217 - val_acc: 0.9079 - val_recall: 0.9042 - val_precision: 0.9099 - val_f1_score: 0.8927
# Epoch 00033: early stopping
#
# Iter #  4 starting
#
# Epoch 1/100
#   2/622 [..............................] - ETA: 14:40 - loss: 0.6746 - acc: 0.2692 - recall: 0.5893 - precision: 0.2374 - f1_score: 0.2788WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.4274s vs `on_train_batch_end` time: 2.4141s). Check your callbacks.
# 622/622 [==============================] - ETA: 0s - loss: 0.1428 - acc: 0.8471 - recall: 0.8140 - precision: 0.8662 - f1_score: 0.8348
# Epoch 00001: val_f1_score improved from -inf to 0.87646, saving model to /app/_data/models/final/eff5FullTrain/Eff5FullTrain_4.h5
# 622/622 [==============================] - 291s 468ms/step - loss: 0.1428 - acc: 0.8471 - recall: 0.8140 - precision: 0.8662 - f1_score: 0.8348 - val_loss: 0.1018 - val_acc: 0.8824 - val_recall: 0.8660 - val_precision: 0.9110 - val_f1_score: 0.8765
# Epoch 2/100
# 622/622 [==============================] - ETA: 0s - loss: 0.1031 - acc: 0.8884 - recall: 0.8656 - precision: 0.8994 - f1_score: 0.8765
# Epoch 00002: val_f1_score improved from 0.87646 to 0.89267, saving model to /app/_data/models/final/eff5FullTrain/Eff5FullTrain_4.h5
# 622/622 [==============================] - 286s 460ms/step - loss: 0.1031 - acc: 0.8884 - recall: 0.8656 - precision: 0.8994 - f1_score: 0.8765 - val_loss: 0.0898 - val_acc: 0.9067 - val_recall: 0.8727 - val_precision: 0.9272 - val_f1_score: 0.8927
# Epoch 3/100
# 622/622 [==============================] - ETA: 0s - loss: 0.0963 - acc: 0.8980 - recall: 0.8778 - precision: 0.9053 - f1_score: 0.8848
# Epoch 00003: val_f1_score did not improve from 0.89267
# 622/622 [==============================] - 286s 460ms/step - loss: 0.0963 - acc: 0.8980 - recall: 0.8778 - precision: 0.9053 - f1_score: 0.8848 - val_loss: 0.0903 - val_acc: 0.8965 - val_recall: 0.8847 - val_precision: 0.9109 - val_f1_score: 0.8772
# Epoch 4/100
# 622/622 [==============================] - ETA: 0s - loss: 0.0874 - acc: 0.9057 - recall: 0.8904 - precision: 0.9141 - f1_score: 0.8931
# Epoch 00004: val_f1_score did not improve from 0.89267
# 622/622 [==============================] - 287s 461ms/step - loss: 0.0874 - acc: 0.9057 - recall: 0.8904 - precision: 0.9141 - f1_score: 0.8931 - val_loss: 0.0930 - val_acc: 0.8973 - val_recall: 0.8967 - val_precision: 0.9013 - val_f1_score: 0.8857
# Epoch 5/100
# 622/622 [==============================] - ETA: 0s - loss: 0.0832 - acc: 0.9097 - recall: 0.8956 - precision: 0.9208 - f1_score: 0.8988
# Epoch 00005: val_f1_score did not improve from 0.89267
# 622/622 [==============================] - 289s 465ms/step - loss: 0.0832 - acc: 0.9097 - recall: 0.8956 - precision: 0.9208 - f1_score: 0.8988 - val_loss: 0.1091 - val_acc: 0.8747 - val_recall: 0.8964 - val_precision: 0.8721 - val_f1_score: 0.8682
# Epoch 6/100
# 622/622 [==============================] - ETA: 0s - loss: 0.0820 - acc: 0.9087 - recall: 0.8989 - precision: 0.9147 - f1_score: 0.8959
# Epoch 00006: val_f1_score improved from 0.89267 to 0.90003, saving model to /app/_data/models/final/eff5FullTrain/Eff5FullTrain_4.h5
# 622/622 [==============================] - 290s 466ms/step - loss: 0.0820 - acc: 0.9087 - recall: 0.8989 - precision: 0.9147 - f1_score: 0.8959 - val_loss: 0.0849 - val_acc: 0.9124 - val_recall: 0.8909 - val_precision: 0.9248 - val_f1_score: 0.9000
# Epoch 7/100
# 622/622 [==============================] - ETA: 0s - loss: 0.0742 - acc: 0.9178 - recall: 0.9072 - precision: 0.9251 - f1_score: 0.9060
# Epoch 00007: val_f1_score did not improve from 0.90003
# 622/622 [==============================] - 287s 462ms/step - loss: 0.0742 - acc: 0.9178 - recall: 0.9072 - precision: 0.9251 - f1_score: 0.9060 - val_loss: 0.2115 - val_acc: 0.8496 - val_recall: 0.8469 - val_precision: 0.8737 - val_f1_score: 0.8376
# Epoch 8/100
# 622/622 [==============================] - ETA: 0s - loss: 0.0708 - acc: 0.9207 - recall: 0.9118 - precision: 0.9291 - f1_score: 0.9090
# Epoch 00008: val_f1_score improved from 0.90003 to 0.90285, saving model to /app/_data/models/final/eff5FullTrain/Eff5FullTrain_4.h5
# 622/622 [==============================] - 287s 461ms/step - loss: 0.0708 - acc: 0.9207 - recall: 0.9118 - precision: 0.9291 - f1_score: 0.9090 - val_loss: 0.0814 - val_acc: 0.9166 - val_recall: 0.9126 - val_precision: 0.9128 - val_f1_score: 0.9029
# Epoch 9/100
# 622/622 [==============================] - ETA: 0s - loss: 0.0700 - acc: 0.9200 - recall: 0.9096 - precision: 0.9281 - f1_score: 0.9079
# Epoch 00009: val_f1_score did not improve from 0.90285
# 622/622 [==============================] - 287s 461ms/step - loss: 0.0700 - acc: 0.9200 - recall: 0.9096 - precision: 0.9281 - f1_score: 0.9079 - val_loss: 0.0824 - val_acc: 0.9074 - val_recall: 0.9121 - val_precision: 0.9088 - val_f1_score: 0.8959
# Epoch 10/100
# 622/622 [==============================] - ETA: 0s - loss: 0.0655 - acc: 0.9243 - recall: 0.9180 - precision: 0.9316 - f1_score: 0.9122
# Epoch 00010: val_f1_score did not improve from 0.90285
# 622/622 [==============================] - 290s 466ms/step - loss: 0.0655 - acc: 0.9243 - recall: 0.9180 - precision: 0.9316 - f1_score: 0.9122 - val_loss: 0.0803 - val_acc: 0.9074 - val_recall: 0.9112 - val_precision: 0.9072 - val_f1_score: 0.8914
# Epoch 11/100
# 622/622 [==============================] - ETA: 0s - loss: 0.0649 - acc: 0.9250 - recall: 0.9218 - precision: 0.9310 - f1_score: 0.9132
# Epoch 00011: val_f1_score improved from 0.90285 to 0.90718, saving model to /app/_data/models/final/eff5FullTrain/Eff5FullTrain_4.h5
# 622/622 [==============================] - 290s 466ms/step - loss: 0.0649 - acc: 0.9250 - recall: 0.9218 - precision: 0.9310 - f1_score: 0.9132 - val_loss: 0.0813 - val_acc: 0.9231 - val_recall: 0.9186 - val_precision: 0.9125 - val_f1_score: 0.9072
# Epoch 12/100
# 622/622 [==============================] - ETA: 0s - loss: 0.0607 - acc: 0.9295 - recall: 0.9277 - precision: 0.9375 - f1_score: 0.9185
# Epoch 00012: val_f1_score did not improve from 0.90718
# 622/622 [==============================] - 290s 466ms/step - loss: 0.0607 - acc: 0.9295 - recall: 0.9277 - precision: 0.9375 - f1_score: 0.9185 - val_loss: 0.0774 - val_acc: 0.9199 - val_recall: 0.9211 - val_precision: 0.9165 - val_f1_score: 0.9065
# Epoch 13/100
# 622/622 [==============================] - ETA: 0s - loss: 0.0594 - acc: 0.9305 - recall: 0.9275 - precision: 0.9383 - f1_score: 0.9199
# Epoch 00013: val_f1_score improved from 0.90718 to 0.91291, saving model to /app/_data/models/final/eff5FullTrain/Eff5FullTrain_4.h5
# 622/622 [==============================] - 286s 460ms/step - loss: 0.0594 - acc: 0.9305 - recall: 0.9275 - precision: 0.9383 - f1_score: 0.9199 - val_loss: 0.0746 - val_acc: 0.9303 - val_recall: 0.9218 - val_precision: 0.9308 - val_f1_score: 0.9129
# Epoch 14/100
# 622/622 [==============================] - ETA: 0s - loss: 0.0561 - acc: 0.9351 - recall: 0.9313 - precision: 0.9429 - f1_score: 0.9232
# Epoch 00014: val_f1_score did not improve from 0.91291
# 622/622 [==============================] - 290s 466ms/step - loss: 0.0561 - acc: 0.9351 - recall: 0.9313 - precision: 0.9429 - f1_score: 0.9232 - val_loss: 0.0982 - val_acc: 0.8851 - val_recall: 0.8879 - val_precision: 0.9136 - val_f1_score: 0.8870
# Epoch 15/100
# 622/622 [==============================] - ETA: 0s - loss: 0.0548 - acc: 0.9343 - recall: 0.9315 - precision: 0.9432 - f1_score: 0.9238
# Epoch 00015: val_f1_score did not improve from 0.91291
# 622/622 [==============================] - 287s 462ms/step - loss: 0.0548 - acc: 0.9343 - recall: 0.9315 - precision: 0.9432 - f1_score: 0.9238 - val_loss: 0.0933 - val_acc: 0.9052 - val_recall: 0.8985 - val_precision: 0.9143 - val_f1_score: 0.8968
# Epoch 16/100
# 622/622 [==============================] - ETA: 0s - loss: 0.0502 - acc: 0.9369 - recall: 0.9373 - precision: 0.9482 - f1_score: 0.9273
# Epoch 00016: val_f1_score did not improve from 0.91291
# 622/622 [==============================] - 289s 465ms/step - loss: 0.0502 - acc: 0.9369 - recall: 0.9373 - precision: 0.9482 - f1_score: 0.9273 - val_loss: 0.0852 - val_acc: 0.9176 - val_recall: 0.9264 - val_precision: 0.9115 - val_f1_score: 0.9052
# Epoch 17/100
# 622/622 [==============================] - ETA: 0s - loss: 0.0497 - acc: 0.9365 - recall: 0.9374 - precision: 0.9467 - f1_score: 0.9269
# Epoch 00017: val_f1_score improved from 0.91291 to 0.91412, saving model to /app/_data/models/final/eff5FullTrain/Eff5FullTrain_4.h5
# 622/622 [==============================] - 290s 466ms/step - loss: 0.0497 - acc: 0.9365 - recall: 0.9374 - precision: 0.9467 - f1_score: 0.9269 - val_loss: 0.0724 - val_acc: 0.9310 - val_recall: 0.9244 - val_precision: 0.9246 - val_f1_score: 0.9141
# Epoch 18/100
# 622/622 [==============================] - ETA: 0s - loss: 0.
100
# 622/622 [==============================] - ETA: 0s - loss: 0.0600 - acc: 0.9280 - recall: 0.9250 - precision: 0.9394 - f1_score: 0.9186
# Epoch 00013: val_f1_score did not improve from 0.90891
# 622/622 [==============================] - 283s 455ms/step - loss: 0.0600 - acc: 0.9280 - recall: 0.9250 - precision: 0.9394 - f1_score: 0.9186 - val_loss: 0.0811 - val_acc: 0.9089 - val_recall: 0.9010 - val_precision: 0.9190 - val_f1_score: 0.8990
# Epoch 14/100
# 622/622 [==============================] - ETA: 0s - loss: 0.0572 - acc: 0.9297 - recall: 0.9298 - precision: 0.9416 - f1_score: 0.9206
# Epoch 00014: val_f1_score did not improve from 0.90891
# 622/622 [==============================] - 280s 451ms/step - loss: 0.0572 - acc: 0.9297 - recall: 0.9298 - precision: 0.9416 - f1_score: 0.9206 - val_loss: 0.0800 - val_acc: 0.9171 - val_recall: 0.8957 - val_precision: 0.9351 - val_f1_score: 0.9043
# Epoch 15/100
# 622/622 [==============================] - ETA: 0s - loss: 0.0549 - acc: 0.9338 - recall: 0.9337 - precision: 0.9457 - f1_score: 0.9240
# Epoch 00015: val_f1_score did not improve from 0.90891
# 622/622 [==============================] - 280s 450ms/step - loss: 0.0549 - acc: 0.9338 - recall: 0.9337 - precision: 0.9457 - f1_score: 0.9240 - val_loss: 0.0825 - val_acc: 0.9248 - val_recall: 0.9054 - val_precision: 0.9327 - val_f1_score: 0.9072
# Epoch 16/100
# 622/622 [==============================] - ETA: 0s - loss: 0.0523 - acc: 0.9383 - recall: 0.9372 - precision: 0.9465 - f1_score: 0.9272
# Epoch 00016: val_f1_score did not improve from 0.90891
# 622/622 [==============================] - 279s 448ms/step - loss: 0.0523 - acc: 0.9383 - recall: 0.9372 - precision: 0.9465 - f1_score: 0.9272 - val_loss: 0.0764 - val_acc: 0.9164 - val_recall: 0.9227 - val_precision: 0.9267 - val_f1_score: 0.9081
# Epoch 17/100
# 622/622 [==============================] - ETA: 0s - loss: 0.0517 - acc: 0.9358 - recall: 0.9384 - precision: 0.9483 - f1_score: 0.9278
# Epoch 00017: val_f1_score did not improve from 0.90891
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 0.0004500000213738531.
# 622/622 [==============================] - 280s 450ms/step - loss: 0.0517 - acc: 0.9358 - recall: 0.9384 - precision: 0.9483 - f1_score: 0.9278 - val_loss: 0.0798 - val_acc: 0.9241 - val_recall: 0.9296 - val_precision: 0.9113 - val_f1_score: 0.9089
# Epoch 18/100
# 622/622 [==============================] - ETA: 0s - loss: 0.0457 - acc: 0.9437 - recall: 0.9445 - precision: 0.9553 - f1_score: 0.9330
# Epoch 00018: val_f1_score improved from 0.90891 to 0.91166, saving model to /app/_data/models/final/eff5FullTrain/Eff5FullTrain_5.h5
# 622/622 [==============================] - 285s 457ms/step - loss: 0.0457 - acc: 0.9437 - recall: 0.9445 - precision: 0.9553 - f1_score: 0.9330 - val_loss: 0.0798 - val_acc: 0.9261 - val_recall: 0.9160 - val_precision: 0.9305 - val_f1_score: 0.9117
# Epoch 19/100
# 622/622 [==============================] - ETA: 0s - loss: 0.0432 - acc: 0.9425 - recall: 0.9477 - precision: 0.9558 - f1_score: 0.9346
# Epoch 00019: val_f1_score did not improve from 0.91166
# 622/622 [==============================] - 285s 459ms/step - loss: 0.0432 - acc: 0.9425 - recall: 0.9477 - precision: 0.9558 - f1_score: 0.9346 - val_loss: 0.0817 - val_acc: 0.9154 - val_recall: 0.9277 - val_precision: 0.9203 - val_f1_score: 0.9080
# Epoch 20/100
# 622/622 [==============================] - ETA: 0s - loss: 0.0409 - acc: 0.9472 - recall: 0.9502 - precision: 0.9588 - f1_score: 0.9375
# Epoch 00020: val_f1_score did not improve from 0.91166
# 622/622 [==============================] - 283s 456ms/step - loss: 0.0409 - acc: 0.9472 - recall: 0.9502 - precision: 0.9588 - f1_score: 0.9375 - val_loss: 0.0789 - val_acc: 0.9256 - val_recall: 0.9162 - val_precision: 0.9358 - val_f1_score: 0.9108
# Epoch 21/100
# 622/622 [==============================] - ETA: 0s - loss: 0.0393 - acc: 0.9443 - recall: 0.9525 - precision: 0.9596 - f1_score: 0.9374
# Epoch 00021: val_f1_score improved from 0.91166 to 0.91261, saving model to /app/_data/models/final/eff5FullTrain/Eff5FullTrain_5.h5
# 622/622 [==============================] - 285s 459ms/step - loss: 0.0393 - acc: 0.9443 - recall: 0.9525 - precision: 0.9596 - f1_score: 0.9374 - val_loss: 0.0799 - val_acc: 0.9303 - val_recall: 0.9307 - val_precision: 0.9199 - val_f1_score: 0.9126
# Epoch 22/100
# 622/622 [==============================] - ETA: 0s - loss: 0.0381 - acc: 0.9465 - recall: 0.9564 - precision: 0.9607 - f1_score: 0.9392
# Epoch 00022: val_f1_score did not improve from 0.91261
# 622/622 [==============================] - 278s 447ms/step - loss: 0.0381 - acc: 0.9465 - recall: 0.9564 - precision: 0.9607 - f1_score: 0.9392 - val_loss: 0.0796 - val_acc: 0.9218 - val_recall: 0.9148 - val_precision: 0.9272 - val_f1_score: 0.9083
# Epoch 23/100
# 622/622 [==============================] - ETA: 0s - loss: 0.0359 - acc: 0.9505 - recall: 0.9575 - precision: 0.9633 - f1_score: 0.9416
# Epoch 00023: val_f1_score did not improve from 0.91261
# 622/622 [==============================] - 283s 455ms/step - loss: 0.0359 - acc: 0.9505 - recall: 0.9575 - precision: 0.9633 - f1_score: 0.9416 - val_loss: 0.0843 - val_acc: 0.9171 - val_recall: 0.9270 - val_precision: 0.9165 - val_f1_score: 0.9090
# Epoch 24/100
# 622/622 [==============================] - ETA: 0s - loss: 0.0359 - acc: 0.9486 - recall: 0.9570 - precision: 0.9638 - f1_score: 0.9417
# Epoch 00024: val_f1_score did not improve from 0.91261
# 622/622 [==============================] - 284s 457ms/step - loss: 0.0359 - acc: 0.9486 - recall: 0.9570 - precision: 0.9638 - f1_score: 0.9417 - val_loss: 0.0869 - val_acc: 0.9268 - val_recall: 0.9167 - val_precision: 0.9341 - val_f1_score: 0.9098
# Epoch 25/100
# 622/622 [==============================] - ETA: 0s - loss: 0.0346 - acc: 0.9515 - recall: 0.9606 - precision: 0.9652 - f1_score: 0.9429
# Epoch 00025: val_f1_score did not improve from 0.91261
# 622/622 [==============================] - 282s 453ms/step - loss: 0.0346 - acc: 0.9515 - recall: 0.9606 - precision: 0.9652 - f1_score: 0.9429 - val_loss: 0.0913 - val_acc: 0.9258 - val_recall: 0.9093 - val_precision: 0.9288 - val_f1_score: 0.9095
# Epoch 26/100
# 622/622 [==============================] - ETA: 0s - loss: 0.0295 - acc: 0.9502 - recall: 0.9657 - precision: 0.9691 - f1_score: 0.9453
# Epoch 00026: val_f1_score improved from 0.91261 to 0.91418, saving model to /app/_data/models/final/eff5FullTrain/Eff5FullTrain_5.h5
# 622/622 [==============================] - 282s 453ms/step - loss: 0.0295 - acc: 0.9502 - recall: 0.9657 - precision: 0.9691 - f1_score: 0.9453 - val_loss: 0.0857 - val_acc: 0.9320 - val_recall: 0.9351 - val_precision: 0.9188 - val_f1_score: 0.9142
# Epoch 27/100
# 622/622 [==============================] - ETA: 0s - loss: 0.
100
# 622/622 [==============================] - ETA: 0s - loss: 0.0158 - acc: 0.9597 - recall: 0.9822 - precision: 0.9846 - f1_score: 0.9597
# Epoch 00041: val_f1_score did not improve from 0.91686
# 622/622 [==============================] - 283s 454ms/step - loss: 0.0158 - acc: 0.9597 - recall: 0.9822 - precision: 0.9846 - f1_score: 0.9597 - val_loss: 0.1136 - val_acc: 0.9203 - val_recall: 0.9222 - val_precision: 0.9241 - val_f1_score: 0.9100
# Epoch 42/100
# 622/622 [==============================] - ETA: 0s - loss: 0.0161 - acc: 0.9607 - recall: 0.9820 - precision: 0.9847 - f1_score: 0.9584
# Epoch 00042: val_f1_score did not improve from 0.91686
# 622/622 [==============================] - 286s 459ms/step - loss: 0.0161 - acc: 0.9607 - recall: 0.9820 - precision: 0.9847 - f1_score: 0.9584 - val_loss: 0.1227 - val_acc: 0.9181 - val_recall: 0.9157 - val_precision: 0.9128 - val_f1_score: 0.9051
# Epoch 43/100
# 622/622 [==============================] - ETA: 0s - loss: 0.0182 - acc: 0.9603 - recall: 0.9799 - precision: 0.9828 - f1_score: 0.9575Restoring model weights from the end of the best epoch.
#
# Epoch 00043: val_f1_score did not improve from 0.91686
# 622/622 [==============================] - 282s 453ms/step - loss: 0.0182 - acc: 0.9603 - recall: 0.9799 - precision: 0.9828 - f1_score: 0.9575 - val_loss: 0.1174 - val_acc: 0.9275 - val_recall: 0.9243 - val_precision: 0.9230 - val_f1_score: 0.9120
# Epoch 00043: early stopping

# %%
tf.config.list_physical_devices("GPU")
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
def parse_all(file_path):
    img = tf.io.read_file(TRAIN_IMG_PATH + file_path)
    img = tf.image.decode_jpeg(img, channels=3)
    return img


def predict_new(path, model):
    img = parse_all(path)
    img = tf.expand_dims(img, axis=0)
    pred = model.predict(img)
    return pred_to_labels(pred[0])

# %%
df_sub = pd.DataFrame(columns=["image", "labels"])
for img_name in os.listdir(TRAIN_IMG_PATH):
    pred = predict_new(img_name, model)

    df_sub = df_sub.append({"image": img_name, "labels": pred}, ignore_index=True)

print(df_sub.head())
# Out:
#                   image                   labels
# 0  bfc6d90f402f4c34.jpg  frog_eye_leaf_spot scab
# 1  9eb93fe282326266.jpg           powdery_mildew
# 2  f4cb3a8f41b413e4.jpg       frog_eye_leaf_spot
# 3  98322eab16bef2c1.jpg                     rust
# 4  dad5d6250cae80b7.jpg                  complex

# %%
df_sub = df_sub.merge(
    labels_21_20[["image", "labels"]],
    on="image",
    how="left",
    suffixes=("_pred", "_true"),
)

# %%
df_sub.to_csv("/app/sandbox/wrong_predictions/eff4/eff4_ns_cropped_2.csv")

# %%
df_sub[df_sub["labels_pred"] == ""]["labels_true"].value_counts()
# Out:
# complex                    22
# scab                       10
# rust                        7
# frog_eye_leaf_spot          5
# scab frog_eye_leaf_spot     1
# rust frog_eye_leaf_spot     1
# powdery_mildew complex      1
# powdery_mildew              1
# healthy                     1
# Name: labels_true, dtype: int64

# %%
df_sub[df_sub["labels_pred"] != df_sub["labels_true"]]["labels_true"].value_counts()
# Out:
# scab frog_eye_leaf_spot            682
# complex                            438
# scab frog_eye_leaf_spot complex    200
# frog_eye_leaf_spot complex         165
# scab                               124
# rust frog_eye_leaf_spot            118
# rust complex                        91
# powdery_mildew complex              87
# rust                                74
# frog_eye_leaf_spot                  71
# healthy                             19
# powdery_mildew                       7
# Name: labels_true, dtype: int64
