# %%
import kaggle
# Out:
# Warning: Your Kaggle API key is readable by other users on this system! To fix this, you can run 'chmod 600 /app/kaggle.json'

# %%
! kaggle datasets init -p /app/_data/models/final/Eff5HandComplex/
# Out:
# Warning: Your Kaggle API key is readable by other users on this system! To fix this, you can run 'chmod 600 /app/kaggle.json'
# Data package template written to: /app/_data/models/final/Eff5HandComplex/dataset-metadata.json

# %%
! kaggle datasets create -p /app/_data/models/final/Eff5HandComplex/
# Out:
# Warning: Your Kaggle API key is readable by other users on this system! To fix this, you can run 'chmod 600 /app/kaggle.json'
# Starting upload for file Eff5HandComplex_5.h5
# 100%|█████████████████████████████████████████| 327M/327M [08:27<00:00, 676kB/s]
# Upload successful: Eff5HandComplex_5.h5 (327MB)
# Starting upload for file Eff5HandComplex_3.h5
# 100%|█████████████████████████████████████████| 327M/327M [08:30<00:00, 672kB/s]
# Upload successful: Eff5HandComplex_3.h5 (327MB)
# Skipping folder: backup; use '--dir-mode' to upload folders
# Starting upload for file Eff5HandComplex_2.h5
# 100%|█████████████████████████████████████████| 327M/327M [08:53<00:00, 643kB/s]
# Upload successful: Eff5HandComplex_2.h5 (327MB)
# Starting upload for file Eff5HandComplex_1.h5
# 100%|█████████████████████████████████████████| 327M/327M [08:26<00:00, 677kB/s]
# Upload successful: Eff5HandComplex_1.h5 (327MB)
# Starting upload for file Eff5HandComplex_4.h5
# 100%|█████████████████████████████████████████| 327M/327M [08:38<00:00, 661kB/s]
# Upload successful: Eff5HandComplex_4.h5 (327MB)
# Skipping folder: .ipynb_checkpoints; use '--dir-mode' to upload folders
# Your private Dataset is being created. Please check progress at https://www.kaggle.com/nataliayurasova/Eff5HandComplex

# %%
! pip install albumentations
import albumentations
# Out:
# Collecting albumentations
#   Downloading albumentations-0.5.2-py3-none-any.whl (72 kB)
#      |████████████████████████████████| 72 kB 438 kB/s eta 0:00:011
# Collecting scikit-image>=0.16.1
#   Downloading scikit_image-0.18.1-cp38-cp38-manylinux1_x86_64.whl (30.2 MB)
#      |████████████████████████████████| 30.2 MB 16.1 MB/s eta 0:00:01
# Requirement already satisfied: scipy in /usr/local/lib/python3.8/dist-packages (from albumentations) (1.4.1)
# Collecting imgaug>=0.4.0
#   Downloading imgaug-0.4.0-py2.py3-none-any.whl (948 kB)
#      |████████████████████████████████| 948 kB 22.0 MB/s eta 0:00:01
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.8/dist-packages (from albumentations) (5.3.1)
# Requirement already satisfied: numpy>=1.11.1 in /usr/local/lib/python3.8/dist-packages (from albumentations) (1.17.3)
# Collecting opencv-python-headless>=4.1.1
#   Downloading opencv_python_headless-4.5.2.52-cp38-cp38-manylinux2014_x86_64.whl (38.2 MB)
#      |████████████████████████████████| 38.2 MB 11.9 MB/s eta 0:00:01
# Collecting opencv-python
#   Downloading opencv_python-4.5.2.52-cp38-cp38-manylinux2014_x86_64.whl (51.0 MB)
#      |████████████████████████████████| 51.0 MB 91 kB/s s eta 0:00:01
# Collecting imageio
#   Downloading imageio-2.9.0-py3-none-any.whl (3.3 MB)
#      |████████████████████████████████| 3.3 MB 23.6 MB/s eta 0:00:01
# Requirement already satisfied: Pillow in /usr/local/lib/python3.8/dist-packages (from imgaug>=0.4.0->albumentations) (8.2.0)
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from imgaug>=0.4.0->albumentations) (1.15.0)
# Collecting Shapely
#   Downloading Shapely-1.7.1-cp38-cp38-manylinux1_x86_64.whl (1.0 MB)
#      |████████████████████████████████| 1.0 MB 23.5 MB/s eta 0:00:01
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.8/dist-packages (from imgaug>=0.4.0->albumentations) (3.4.1)
# Collecting PyWavelets>=1.1.1
#   Downloading PyWavelets-1.1.1-cp38-cp38-manylinux1_x86_64.whl (4.4 MB)
#      |████████████████████████████████| 4.4 MB 19.9 MB/s eta 0:00:01
# Collecting networkx>=2.0
#   Downloading networkx-2.5.1-py3-none-any.whl (1.6 MB)
#      |████████████████████████████████| 1.6 MB 23.8 MB/s eta 0:00:01
# Collecting tifffile>=2019.7.26
#   Downloading tifffile-2021.4.8-py3-none-any.whl (165 kB)
#      |████████████████████████████████| 165 kB 25.2 MB/s eta 0:00:01
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.8/dist-packages (from matplotlib->imgaug>=0.4.0->albumentations) (0.10.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib->imgaug>=0.4.0->albumentations) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.8/dist-packages (from matplotlib->imgaug>=0.4.0->albumentations) (2.8.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib->imgaug>=0.4.0->albumentations) (1.3.1)
# Requirement already satisfied: decorator<5,>=4.3 in /usr/local/lib/python3.8/dist-packages (from networkx>=2.0->scikit-image>=0.16.1->albumentations) (4.4.2)
# Installing collected packages: tifffile, PyWavelets, networkx, imageio, Shapely, scikit-image, opencv-python, opencv-python-headless, imgaug, albumentations
# Successfully installed PyWavelets-1.1.1 Shapely-1.7.1 albumentations-0.5.2 imageio-2.9.0 imgaug-0.4.0 networkx-2.5.1 opencv-python-4.5.2.52 opencv-python-headless-4.5.2.52 scikit-image-0.18.1 tifffile-2021.4.8
# WARNING: You are using pip version 21.0.1; however, version 21.1.1 is available.
# You should consider upgrading via the '/usr/bin/python -m pip install --upgrade pip' command.

# %%
import os

import numpy as np
import pandas as pd
from IPython.core.interactiveshell import InteractiveShell

InteractiveShell.ast_node_interactivity = "all"
import warnings

warnings.filterwarnings("ignore")

import matplotlib.pyplot as plt
import sklearn
import tensorflow as tf
import tensorflow_addons as tfa
from PIL import Image
from sklearn.model_selection import (
    StratifiedKFold,
    StratifiedShuffleSplit,
    train_test_split,
)
from tensorflow import keras
from tensorflow.keras.applications.efficientnet import EfficientNetB4, EfficientNetB7
from tensorflow.keras.layers import (
    AveragePooling2D,
    AvgPool2D,
    Conv2D,
    Dense,
    Flatten,
    GlobalAveragePooling2D,
    MaxPooling2D,
)
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tqdm import notebook, tqdm

# %matplotlib inline

# %%
tf.config.list_physical_devices("GPU")
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
PATH = "/app/_data/"
BATCH_SIZE = 26
SEED = 37
IMAGE_SIZE = 456
NUM_CLASSES = 6
TRAIN_IMG_PATH = "/app/_data/456_npy/"
TEST_IMG_PATH = "/app/_data/test_images/"
feature_columns = [
    "complex",
    "frog_eye_leaf_spot",
    "healthy",
    "powdery_mildew",
    "rust",
    "scab",
]
wrong = [
    "ead085dfac287263.jpg",
    "95276ccd226ad933.jpg",
    "da8770e819d2696d.jpg",
    "cd3a1d64e6806eb5.jpg",
    "ccec54723ff91860.jpg",
]

# %%
df_labels = pd.read_csv("/app/_data/df_csv/labels_21_20.csv", index_col=[0])
df_labels = df_labels.query("image not in @wrong").reset_index(drop=True)

# %%
complex_labeled1 = pd.read_csv('/app/_data/models/final/Eff5HandComplex/backup/complex1_labels.csv')
complex_labeled2 = pd.read_csv('/app/_data/models/final/Eff5HandComplex/backup/complex2_labels.csv')
complex_labeled = pd.concat([complex_labeled1, complex_labeled2], axis=0, ignore_index=True)
complex_labeled['image'] = complex_labeled['image'].apply(lambda x: x.split('/')[-1])
complex_labeled['image'] = complex_labeled['image'].apply(lambda x: x.split('_')[0])
complex_labeled['image'] = complex_labeled['image'].apply(lambda x: x.split('.')[0])
complex_labeled['image'] = complex_labeled['image']+'.jpg'
complex_labeled = complex_labeled[['image', 'choice']]
complex_labeled.columns = ['image', 'labels']
complex_labeled = complex_labeled.join(complex_labeled['labels'].str.get_dummies(' '))

# %%
df= pd.DataFrame(columns = complex_labeled.columns)
for image in complex_labeled[complex_labeled['image'].duplicated(keep=False)]['image']:
    df.loc[image, 'image'] = image
    for column in feature_columns:
        if complex_labeled[complex_labeled['image']==image][column].sum() == 2:
            df.loc[image, column] =1
        else:
            df.loc[image, column] = 0
    df.loc[image, 'labels'] = ' '.join([feature_columns[i] for i in range(len(feature_columns)) if df.loc[image, feature_columns].values[i]==1])

# %%
dup_list= complex_labeled[complex_labeled['image'].duplicated(keep=False)]['image'].tolist()
complex_labeled = complex_labeled.query('image not in @dup_list')
complex_labeled = pd.concat([complex_labeled, df], axis=0, ignore_index=True)

# %%
complex_labeled = complex_labeled.dropna(axis=0)

# %%
# complex_labeled.to_csv('/app/_data/models/final/Eff5HandComplex/backup/complex_labels.csv', index=False)

# %%
df_complex = df_labels.query('labels == "complex"').reset_index(drop=True)
df_without_complex = df_labels.query('labels != "complex"').reset_index(drop=True)
df_labels = pd.concat([df_without_complex, complex_labeled], axis=0, ignore_index=True).sample(frac=1, random_state=SEED).reset_index(drop=True)
df_labels["image"] = df_labels["image"].str.replace(".jpg", ".npy")

# %%
df_labels
# Out:
#                       image              labels complex frog_eye_leaf_spot  \
# 0      f49ab56b4f920b21.npy                scab       0                  0
# 1      e924dd52942f9e4c.npy                rust       0                  0
# 2      fa3f80ea9c4b1a58.npy                rust       0                  0
# 3      adc27f0e7ca55510.npy                scab       0                  0
# 4      db652835372c9758.npy                rust       0                  0
# ...                     ...                 ...     ...                ...
# 20299  dbd2388b673c44e4.npy             healthy       0                  0
# 20300  a4b57ed29e341619.npy  frog_eye_leaf_spot       0                  1
# 20301  87b58bdb956a8164.npy                scab       0                  0
# 20302  c4ef976cb1ca304a.npy  frog_eye_leaf_spot       0                  1
# 20303  90f45f2e2d1e2789.npy             healthy       0                  0
#
#       healthy powdery_mildew rust scab
# 0           0              0    0    1
# 1           0              0    1    0
# 2           0              0    1    0
# 3           0              0    0    1
# 4           0              0    1    0
# ...       ...            ...  ...  ...
# 20299       1              0    0    0
# 20300       0              0    0    0
# 20301       0              0    0    1
# 20302       0              0    0    0
# 20303       1              0    0    0
#
# [20304 rows x 8 columns]

# %%
# for 380*380
transform = albumentations.Compose(
    [
        albumentations.CLAHE(p=0.1, clip_limit=(1, 2), tile_grid_size=(8, 8)),
        albumentations.OneOf(
            [
                albumentations.MotionBlur((3, 3)),
                albumentations.MedianBlur(blur_limit=3),
                albumentations.GaussianBlur(blur_limit=(3, 3), sigma_limit=0),
                albumentations.Blur(blur_limit=(3, 3)),
            ],
            p=0.2,
        ),
        albumentations.OneOf(
            [
                albumentations.GaussNoise(var_limit=[10, 50], mean=1),
                albumentations.ISONoise(intensity=(0.1, 1), color_shift=(0.01, 0.05)),
                albumentations.ImageCompression(
                    quality_lower=70, quality_upper=100, compression_type=1
                ),
                albumentations.MultiplicativeNoise(
                    multiplier=(0.95, 1.05), per_channel=True, elementwise=True
                ),
                albumentations.Downscale(
                    scale_min=0.6, scale_max=0.99, interpolation=4
                ),
            ],
            p=0.5,
        ),
        albumentations.OneOf(
            [
                albumentations.HueSaturationValue(
                    hue_shift_limit=(-7, 7),
                    sat_shift_limit=(-10, 10),
                    val_shift_limit=(-10, 10),
                ),
                albumentations.RandomBrightnessContrast(
                    brightness_limit=0.15,
                    contrast_limit=0.2,
                    brightness_by_max=True,
                ),
            ],
            p=0.5,
        ),
        albumentations.OneOf(
            [
                albumentations.OpticalDistortion(
                    distort_limit=0.05,
                    shift_limit=0.05,
                    border_mode=2,
                ),
                albumentations.ElasticTransform(
                    alpha=2.0,
                    sigma=50.0,
                    alpha_affine=10.0,
                    interpolation=0,
                    border_mode=2,
                ),
                albumentations.GridDistortion(
                    num_steps=5, distort_limit=0.3, interpolation=0, border_mode=2
                ),
            ],
            p=0.5,
        ),
        albumentations.OneOf(
            [
                albumentations.HorizontalFlip(),
                albumentations.VerticalFlip(),
            ],
            p=0.5,
        ),
        albumentations.OneOf(
            [
                albumentations.Rotate(
                    limit=(-180, 180), interpolation=0, border_mode=2
                ),
                albumentations.ShiftScaleRotate(
                    shift_limit=0.05,
                    scale_limit=0.05,
                    rotate_limit=180,
                    interpolation=0,
                    border_mode=2,
                ),
            ],
            p=0.5,
        ),
    ]
)

# %%
# plt.figure(figsize=(20,20))
# for i, img in enumerate(os.listdir(TRAIN_IMG_PATH)[100:120]):
#     img = np.load(TRAIN_IMG_PATH+img)
#     plt.subplot(4,5,i+1)
#     plt.imshow(img)
# plt.show();

# %%
class Generator(keras.utils.Sequence):
    def __init__(
        self,
        df,
        images_src_dir,
        batch_size,
        target_image_size,
        shuffle=False,
        augment=True,
        crop=False,
        resize=False,
        normalize=False,
    ):
        self.shuffle = shuffle
        self.batch_size = BATCH_SIZE
        self.df = df
        self.images_dir = images_src_dir
        self.target_image_size = (IMAGE_SIZE, IMAGE_SIZE)
        self.augment = augment
        self.crop = crop
        self.resize = resize
        self.normalize = normalize
        # create label index map
        self.labels = self._read_labels()
        self.n_samples = self.df.shape[0]
        self.n_batches = self.n_samples // self.batch_size
        # shuffle data, also repeated after each epoch if needed
        if self.shuffle:
            np.random.shuffle(self.labels)

    def _read_labels(self):
        """
        Returns list images mapping to 1-hot label
        """

        # label indexes
        label_ixs = self.df[feature_columns].values
        image_ixs = self.df["image"].values
        labels = []

        for i in range(len(image_ixs)):
            labels.append([image_ixs[i], label_ixs[i]])
        return labels

    def __len__(self):
        """
        Length in batches
        """
        return self.n_batches

    def __getitem__(self, b_ix):
        """
        Produce batch, by batch index
        """

        assert b_ix < self.n_batches

        b_X = np.zeros(
            (self.batch_size, self.target_image_size[0], self.target_image_size[1], 3),
            dtype=np.uint8,
        )

        b_Y = np.zeros(
            (self.batch_size, self.df[feature_columns].shape[1]),
            dtype=np.uint8,
        )

        for i in range(self.batch_size):
            b_X[i], b_Y[i] = self.get_one(
                i + self.batch_size * b_ix,
            )

        return (b_X, b_Y)

    def get_one(self, one_ix):
        """
        Get single item by absolute index
        """
        id = self.labels[one_ix][0]
        src_file = self.images_dir + id

        # read file
        x = np.load(src_file)
        if self.crop:
            coord = self.df[self.df["image"] == id][
                ["x_min", "y_min", "x_max", "y_max"]
            ].values[0]
            orig_hight = x.shape[0]
            orig_width = x.shape[1]
            x_min = coord[0]
            y_min = coord[1]
            x_max = coord[2]
            y_max = coord[3]
            x = x[
                np.int(y_min * orig_hight) : np.int(y_max * orig_hight),
                np.int(x_min * orig_width) : np.int(x_max * orig_width),
            ]

        y = self.labels[one_ix][1]

        # augment
        if self.augment:
            x = self._augment_image(x)

        # normalize (sample-wise)
        if self.normalize:
            x = x.astype(np.float32)
            x = x - np.mean(x, axis=(0, 1))
            x = x / np.std(x, axis=(0, 1))
        return x.astype(np.uint8), y

    def _augment_image(self, x):
        """
        Randomply augment image
        """

        x = transform(image=x)["image"]
        return x

    def on_epoch_end(self):
        if self.shuffle:
            np.random.shuffle(self.labels)

# %%
gen = Generator(
    df=df_labels.sample(100),
    images_src_dir=TRAIN_IMG_PATH,
    target_image_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    shuffle=False,
    augment=False,
    crop=False,
    resize=False,
)

# %%
gen.__len__()
# Out:
# 3

# %%
policy = keras.mixed_precision.experimental.Policy("mixed_float16")
keras.mixed_precision.experimental.set_policy(policy)
# Out:
# INFO:tensorflow:Mixed precision compatibility check (mixed_float16): OK
# Your GPU will likely run quickly with dtype policy mixed_float16 as it has compute capability of at least 7.0. Your GPU: NVIDIA GeForce RTX 3090, compute capability 8.6

# %%
def get_model():
    inputs = keras.Input(shape=(IMAGE_SIZE, IMAGE_SIZE, 3))
    base_model = keras.applications.EfficientNetB5(weights=None, include_top=False)
    base_model.load_weights(
        "/app/_data/models/efficientnet-b5_noisy-student_notop.h5",
        by_name=True,
        skip_mismatch=True,
    )
    x = base_model(inputs)
    x = keras.layers.GlobalAveragePooling2D(name="avg_pool")(x)
    x = keras.layers.Flatten(name="flatten")(x)
    outputs = keras.layers.Dense(NUM_CLASSES, activation="sigmoid")(x)
    model = keras.Model(inputs=inputs, outputs=outputs)
    model.compile(
        loss="binary_crossentropy",
        optimizer=Adam(lr=0.0005),
        metrics=[
            "acc",
            keras.metrics.Recall(),
            keras.metrics.Precision(),
            tfa.metrics.F1Score(num_classes=NUM_CLASSES, average="weighted"),
        ],
    )
    return model

# %%
skf = StratifiedKFold(n_splits=5, random_state=SEED, shuffle=True)

for i, (train_index, valid_index) in enumerate(
    skf.split(df_labels["image"], df_labels["labels"])
):
    train, valid = df_labels.loc[train_index], df_labels.loc[valid_index]
    model_name = "Eff5HandComplex_" + str(i + 1) + ".h5"
    log_dir = "logs_Eff5HandComplex_" + str(i + 1) + "/"
    print('\nIter # ', str(i+1), 'starting\n')
    callbacks = [
        keras.callbacks.EarlyStopping(
            monitor="val_f1_score",
            patience=12,
            restore_best_weights=True,
            verbose=1,
            mode="max",
        ),
        keras.callbacks.ModelCheckpoint(
            "/app/_data/models/final/Eff5HandComplex/" + model_name,
            monitor="val_f1_score",
            verbose=1,
            save_best_only=True,
            save_weights_only=False,
            mode="max",
            save_freq="epoch",
        ),
        keras.callbacks.ReduceLROnPlateau(
            monitor="val_f1_score",
            factor=0.9,
            patience=8,
            verbose=1,
            mode="max",
            min_delta=1e-4,
            min_lr=0.00000001,
        ),
        keras.callbacks.TensorBoard(
            log_dir="/app/.tensorboard/" + log_dir, histogram_freq=0
        ),
        keras.callbacks.experimental.BackupAndRestore(
            "/app/_data/models/final/Eff5HandComplex/backup/"
        ),
        keras.callbacks.TerminateOnNaN()
    ]

    gen_train = Generator(
        df=train,
        images_src_dir=TRAIN_IMG_PATH,
        target_image_size=IMAGE_SIZE,
        batch_size=BATCH_SIZE,
        shuffle=True,
        augment=True,
        crop=False,
        resize=False,
    )
    gen_valid = Generator(
        df=valid,
        images_src_dir=TRAIN_IMG_PATH,
        target_image_size=IMAGE_SIZE,
        batch_size=BATCH_SIZE,
        shuffle=False,
        augment=False,
        crop=False,
        resize=False,
    )
    model = get_model()
    history = model.fit(
        gen_train,
        validation_data=gen_valid,
        epochs=100,
        steps_per_epoch=train.shape[0] // BATCH_SIZE,
        validation_steps=valid.shape[0] // BATCH_SIZE,
        verbose=1,
        workers=15,
        callbacks=callbacks,
    )
    tf.keras.backend.clear_session()
# Out:
# Iter #  1 starting
#
# Epoch 1/100
#   1/624 [..............................] - ETA: 0s - loss: 0.7339 - acc: 0.1154 - recall: 0.5625 - precision: 0.2000 - f1_score: 0.1419WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/summary_ops_v2.py:1277: stop (from tensorflow.python.eager.profiler) is deprecated and will be removed after 2020-07-01.
# Instructions for updating:
# use `tf.profiler.experimental.stop` instead.
# 624/624 [==============================] - ETA: 0s - loss: 0.1305 - acc: 0.8244 - recall: 0.8536 - precision: 0.8971 - f1_score: 0.8152
# Epoch 00001: val_f1_score improved from -inf to 0.86135, saving model to /app/_data/models/final/Eff5HandComplex/Eff5HandComplex_1.h5
# 624/624 [==============================] - 285s 456ms/step - loss: 0.1305 - acc: 0.8244 - recall: 0.8536 - precision: 0.8971 - f1_score: 0.8152 - val_loss: 0.0779 - val_acc: 0.8676 - val_recall: 0.9323 - val_precision: 0.9260 - val_f1_score: 0.8613
# Epoch 2/100
# 624/624 [==============================] - ETA: 0s - loss: 0.0936 - acc: 0.8556 - recall: 0.9026 - precision: 0.9241 - f1_score: 0.8463
# Epoch 00002: val_f1_score did not improve from 0.86135
# 624/624 [==============================] - 281s 450ms/step - loss: 0.0936 - acc: 0.8556 - recall: 0.9026 - precision: 0.9241 - f1_score: 0.8463 - val_loss: 0.1027 - val_acc: 0.8316 - val_recall: 0.8991 - val_precision: 0.9187 - val_f1_score: 0.8339
# Epoch 3/100
# 624/624 [==============================] - ETA: 0s - loss: 0.0841 - acc: 0.8593 - recall: 0.9103 - precision: 0.9280 - f1_score: 0.8513
# Epoch 00003: val_f1_score did not improve from 0.86135
# 624/624 [==============================] - 282s 452ms/step - loss: 0.0841 - acc: 0.8593 - recall: 0.9103 - precision: 0.9280 - f1_score: 0.8513 - val_loss: 0.0761 - val_acc: 0.8706 - val_recall: 0.9443 - val_precision: 0.9226 - val_f1_score: 0.8553
# Epoch 4/100
# 624/624 [==============================] - ETA: 0s - loss: 0.
100
# 624/624 [==============================] - ETA: 0s - loss: 0.0173 - acc: 0.9140 - recall: 0.9834 - precision: 0.9849 - f1_score: 0.9125
# Epoch 00038: val_f1_score did not improve from 0.89095
# 624/624 [==============================] - 285s 457ms/step - loss: 0.0173 - acc: 0.9140 - recall: 0.9834 - precision: 0.9849 - f1_score: 0.9125 - val_loss: 0.0949 - val_acc: 0.8928 - val_recall: 0.9350 - val_precision: 0.9483 - val_f1_score: 0.8892
# Epoch 39/100
# 624/624 [==============================] - ETA: 0s - loss: 0.0197 - acc: 0.9128 - recall: 0.9793 - precision: 0.9838 - f1_score: 0.9113Restoring model weights from the end of the best epoch.
#
# Epoch 00039: val_f1_score did not improve from 0.89095
# 624/624 [==============================] - 282s 452ms/step - loss: 0.0197 - acc: 0.9128 - recall: 0.9793 - precision: 0.9838 - f1_score: 0.9113 - val_loss: 0.0939 - val_acc: 0.8908 - val_recall: 0.9396 - val_precision: 0.9435 - val_f1_score: 0.8860
# Epoch 00039: early stopping
#
# Iter #  2 starting
#
# Epoch 1/100
#   2/624 [..............................] - ETA: 19:56 - loss: 0.6870 - acc: 0.1923 - recall: 0.5263 - precision: 0.2083 - f1_score: 0.2441WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.4230s vs `on_train_batch_end` time: 3.4233s). Check your callbacks.
# 624/624 [==============================] - ETA: 0s - loss: 0.1346 - acc: 0.8229 - recall: 0.8484 - precision: 0.8937 - f1_score: 0.8131
# Epoch 00001: val_f1_score improved from -inf to 0.82801, saving model to /app/_data/models/final/Eff5HandComplex/Eff5HandComplex_2.h5
# 624/624 [==============================] - 292s 468ms/step - loss: 0.1346 - acc: 0.8229 - recall: 0.8484 - precision: 0.8937 - f1_score: 0.8131 - val_loss: 0.1091 - val_acc: 0.8390 - val_recall: 0.8659 - val_precision: 0.9316 - val_f1_score: 0.8280
# Epoch 2/100
# 624/624 [==============================] - ETA: 0s - loss: 0.0949 - acc: 0.8542 - recall: 0.8985 - precision: 0.9235 - f1_score: 0.8439
# Epoch 00002: val_f1_score improved from 0.82801 to 0.84579, saving model to /app/_data/models/final/Eff5HandComplex/Eff5HandComplex_2.h5
# 624/624 [==============================] - 285s 457ms/step - loss: 0.0949 - acc: 0.8542 - recall: 0.8985 - precision: 0.9235 - f1_score: 0.8439 - val_loss: 0.0948 - val_acc: 0.8506 - val_recall: 0.9051 - val_precision: 0.9304 - val_f1_score: 0.8458
# Epoch 3/100
# 624/624 [==============================] - ETA: 0s - loss: 0.0843 - acc: 0.8643 - recall: 0.9101 - precision: 0.9305 - f1_score: 0.8552
# Epoch 00003: val_f1_score improved from 0.84579 to 0.85372, saving model to /app/_data/models/final/Eff5HandComplex/Eff5HandComplex_2.h5
# 624/624 [==============================] - 289s 462ms/step - loss: 0.0843 - acc: 0.8643 - recall: 0.9101 - precision: 0.9305 - f1_score: 0.8552 - val_loss: 0.0711 - val_acc: 0.8590 - val_recall: 0.9315 - val_precision: 0.9391 - val_f1_score: 0.8537
# Epoch 4/100
# 624/624 [==============================] - ETA: 0s - loss: 0.
100
# 624/624 [==============================] - ETA: 0s - loss: 0.0269 - acc: 0.8986 - recall: 0.9723 - precision: 0.9753 - f1_score: 0.8945
# Epoch 00031: val_f1_score did not improve from 0.88469
# 624/624 [==============================] - 287s 460ms/step - loss: 0.0269 - acc: 0.8986 - recall: 0.9723 - precision: 0.9753 - f1_score: 0.8945 - val_loss: 0.0863 - val_acc: 0.8748 - val_recall: 0.9245 - val_precision: 0.9436 - val_f1_score: 0.8704
# Epoch 32/100
# 624/624 [==============================] - ETA: 0s - loss: 0.0256 - acc: 0.8986 - recall: 0.9732 - precision: 0.9765 - f1_score: 0.8953
# Epoch 00032: val_f1_score improved from 0.88469 to 0.88767, saving model to /app/_data/models/final/Eff5HandComplex/Eff5HandComplex_2.h5
# 624/624 [==============================] - 287s 460ms/step - loss: 0.0256 - acc: 0.8986 - recall: 0.9732 - precision: 0.9765 - f1_score: 0.8953 - val_loss: 0.0808 - val_acc: 0.9048 - val_recall: 0.9278 - val_precision: 0.9513 - val_f1_score: 0.8877
# Epoch 33/100
# 624/624 [==============================] - ETA: 0s - loss: 0.0261 - acc: 0.9013 - recall: 0.9727 - precision: 0.9755 - f1_score: 0.8953
# Epoch 00033: val_f1_score did not improve from 0.88767
# 624/624 [==============================] - 286s 459ms/step - loss: 0.0261 - acc: 0.9013 - recall: 0.9727 - precision: 0.9755 - f1_score: 0.8953 - val_loss: 0.0786 - val_acc: 0.8932 - val_recall: 0.9309 - val_precision: 0.9521 - val_f1_score: 0.8842
# Epoch 34/100
# 624/624 [==============================] - ETA: 0s - loss: 0.0245 - acc: 0.9030 - recall: 0.9744 - precision: 0.9781 - f1_score: 0.8996
# Epoch 00034: val_f1_score did not improve from 0.88767
# 624/624 [==============================] - 287s 460ms/step - loss: 0.0245 - acc: 0.9030 - recall: 0.9744 - precision: 0.9781 - f1_score: 0.8996 - val_loss: 0.0776 - val_acc: 0.8873 - val_recall: 0.9468 - val_precision: 0.9427 - val_f1_score: 0.8842
# Epoch 35/100
# 624/624 [==============================] - ETA: 0s - loss: 0.0236 - acc: 0.9026 - recall: 0.9756 - precision: 0.9784 - f1_score: 0.8995
# Epoch 00035: val_f1_score improved from 0.88767 to 0.88817, saving model to /app/_data/models/final/Eff5HandComplex/Eff5HandComplex_2.h5
# 624/624 [==============================] - 290s 465ms/step - loss: 0.0236 - acc: 0.9026 - recall: 0.9756 - precision: 0.9784 - f1_score: 0.8995 - val_loss: 0.0829 - val_acc: 0.8908 - val_recall: 0.9290 - val_precision: 0.9534 - val_f1_score: 0.8882
# Epoch 36/100
# 624/624 [==============================] - ETA: 0s - loss: 0.0217 - acc: 0.9049 - recall: 0.9782 - precision: 0.9815 - f1_score: 0.9039
# Epoch 00036: val_f1_score did not improve from 0.88817
# 624/624 [==============================] - 284s 455ms/step - loss: 0.0217 - acc: 0.9049 - recall: 0.9782 - precision: 0.9815 - f1_score: 0.9039 - val_loss: 0.0811 - val_acc: 0.8928 - val_recall: 0.9280 - val_precision: 0.9524 - val_f1_score: 0.8852
# Epoch 37/100
# 624/624 [==============================] - ETA: 0s - loss: 0.0218 - acc: 0.9067 - recall: 0.9771 - precision: 0.9805 - f1_score: 0.9056
# Epoch 00037: val_f1_score improved from 0.88817 to 0.90159, saving model to /app/_data/models/final/Eff5HandComplex/Eff5HandComplex_2.h5
# 624/624 [==============================] - 289s 464ms/step - loss: 0.0218 - acc: 0.9067 - recall: 0.9771 - precision: 0.9805 - f1_score: 0.9056 - val_loss: 0.1005 - val_acc: 0.9154 - val_recall: 0.9429 - val_precision: 0.9361 - val_f1_score: 0.9016
# Epoch 38/100
# 624/624 [==============================] - ETA: 0s - loss: 0.
100
# 624/624 [==============================] - ETA: 0s - loss: 0.0125 - acc: 0.9262 - recall: 0.9875 - precision: 0.9892 - f1_score: 0.9294
# Epoch 00059: val_f1_score did not improve from 0.91518
#
# Epoch 00059: ReduceLROnPlateau reducing learning rate to 0.0004500000213738531.
# 624/624 [==============================] - 283s 454ms/step - loss: 0.0125 - acc: 0.9262 - recall: 0.9875 - precision: 0.9892 - f1_score: 0.9294 - val_loss: 0.0983 - val_acc: 0.9112 - val_recall: 0.9451 - val_precision: 0.9469 - val_f1_score: 0.9106
# Epoch 60/100
# 624/624 [==============================] - ETA: 0s - loss: 0.0121 - acc: 0.9326 - recall: 0.9879 - precision: 0.9897 - f1_score: 0.9372
# Epoch 00060: val_f1_score did not improve from 0.91518
# 624/624 [==============================] - 285s 456ms/step - loss: 0.0121 - acc: 0.9326 - recall: 0.9879 - precision: 0.9897 - f1_score: 0.9372 - val_loss: 0.1037 - val_acc: 0.9053 - val_recall: 0.9391 - val_precision: 0.9495 - val_f1_score: 0.9044
# Epoch 61/100
# 624/624 [==============================] - ETA: 0s - loss: 0.0106 - acc: 0.9373 - recall: 0.9886 - precision: 0.9907 - f1_score: 0.9375
# ...
# Epoch 00059: val_f1_score did not improve from 0.90076
# 624/624 [==============================] - 285s 456ms/step - loss: 0.0126 - acc: 0.9316 - recall: 0.9871 - precision: 0.9900 - f1_score: 0.9337 - val_loss: 0.1105 - val_acc: 0.8908 - val_recall: 0.9365 - val_precision: 0.9374 - val_f1_score: 0.8932
# Epoch 60/100
# 624/624 [==============================] - ETA: 0s - loss: 0.0131 - acc: 0.9315 - recall: 0.9865 - precision: 0.9880 - f1_score: 0.9330
# Epoch 00060: val_f1_score did not improve from 0.90076
# 624/624 [==============================] - 281s 450ms/step - loss: 0.0131 - acc: 0.9315 - recall: 0.9865 - precision: 0.9880 - f1_score: 0.9330 - val_loss: 0.1087 - val_acc: 0.8952 - val_recall: 0.9303 - val_precision: 0.9521 - val_f1_score: 0.8932
# Epoch 61/100
# 624/624 [==============================] - ETA: 0s - loss: 0.0138 - acc: 0.9276 - recall: 0.9870 - precision: 0.9887 - f1_score: 0.9289
# Epoch 00061: val_f1_score did not improve from 0.90076
#
# Epoch 00061: ReduceLROnPlateau reducing learning rate to 0.0004500000213738531.
# 624/624 [==============================] - 285s 456ms/step - loss: 0.0138 - acc: 0.9276 - recall: 0.9870 - precision: 0.9887 - f1_score: 0.9289 - val_loss: 0.1096 - val_acc: 0.8984 - val_recall: 0.9340 - val_precision: 0.9350 - val_f1_score: 0.8968
# Epoch 62/100
# 624/624 [==============================] - ETA: 0s - loss: 0.0111 - acc: 0.9304 - recall: 0.9893 - precision: 0.9915 - f1_score: 0.9335
# Epoch 00062: val_f1_score did not improve from 0.90076
# 624/624 [==============================] - 283s 453ms/step - loss: 0.0111 - acc: 0.9304 - recall: 0.9893 - precision: 0.9915 - f1_score: 0.9335 - val_loss: 0.1180 - val_acc: 0.8960 - val_recall: 0.9297 - val_precision: 0.9449 - val_f1_score: 0.8973
# Epoch 63/100
# 624/624 [==============================] - ETA: 0s - loss: 0.0112 - acc: 0.9316 - recall: 0.9894 - precision: 0.9910 - f1_score: 0.9354
# Epoch 00063: val_f1_score did not improve from 0.90076
# 624/624 [==============================] - 283s 453ms/step - loss: 0.0112 - acc: 0.9316 - recall: 0.9894 - precision: 0.9910 - f1_score: 0.9354 - val_loss: 0.1173 - val_acc: 0.8960 - val_recall: 0.9311 - val_precision: 0.9452 - val_f1_score: 0.8978
# Epoch 64/100
# 624/624 [==============================] - ETA: 0s - loss: 0.0093 - acc: 0.9408 - recall: 0.9913 - precision: 0.9920 - f1_score: 0.9426
# Epoch 00064: val_f1_score did not improve from 0.90076
# 624/624 [==============================] - 285s 457ms/step - loss: 0.0093 - acc: 0.9408 - recall: 0.9913 - precision: 0.9920 - f1_score: 0.9426 - val_loss: 0.1181 - val_acc: 0.8947 - val_recall: 0.9315 - val_precision: 0.9515 - val_f1_score: 0.8970
# Epoch 65/100
# 624/624 [==============================] - ETA: 0s - loss: 0.0103 - acc: 0.9347 - recall: 0.9904 - precision: 0.9920 - f1_score: 0.9402
# Epoch 00065: val_f1_score improved from 0.90076 to 0.90613, saving model to /app/_data/models/final/Eff5HandComplex/Eff5HandComplex_5.h5
# 624/624 [==============================] - 287s 460ms/step - loss: 0.0103 - acc: 0.9347 - recall: 0.9904 - precision: 0.9920 - f1_score: 0.9402 - val_loss: 0.1127 - val_acc: 0.9046 - val_recall: 0.9451 - val_precision: 0.9440 - val_f1_score: 0.9061
# Epoch 66/100
# 624/624 [==============================] - ETA: 0s - loss: 0.0098 - acc: 0.9363 - recall: 0.9906 - precision: 0.9919 - f1_score: 0.9400
# Epoch 00066: val_f1_score did not improve from 0.90613
# 624/624 [==============================] - 287s 460ms/step - loss: 0.0098 - acc: 0.9363 - recall: 0.9906 - precision: 0.9919 - f1_score: 0.9400 - val_loss: 0.1084 - val_acc: 0.9029 - val_recall: 0.9406 - val_precision: 0.9422 - val_f1_score: 0.9023
# Epoch 67/100
# 624/624 [==============================] - ETA: 0s - loss: 0.0113 - acc: 0.9330 - recall: 0.9890 - precision: 0.9901 - f1_score: 0.9388
# Epoch 00067: val_f1_score did not improve from 0.90613
# 624/624 [==============================] - 288s 462ms/step - loss: 0.0113 - acc: 0.9330 - recall: 0.9890 - precision: 0.9901 - f1_score: 0.9388 - val_loss: 0.1122 - val_acc: 0.8898 - val_recall: 0.9338 - val_precision: 0.9467 - val_f1_score: 0.8941
# Epoch 68/100
# 624/624 [==============================] - ETA: 0s - loss: 0.0093 - acc: 0.9347 - recall: 0.9911 - precision: 0.9923 - f1_score: 0.9404
# Epoch 00068: val_f1_score improved from 0.90613 to 0.90717, saving model to /app/_data/models/final/Eff5HandComplex/Eff5HandComplex_5.h5
# 624/624 [==============================] - 287s 460ms/step - loss: 0.0093 - acc: 0.9347 - recall: 0.9911 - precision: 0.9923 - f1_score: 0.9404 - val_loss: 0.1368 - val_acc: 0.9046 - val_recall: 0.9439 - val_precision: 0.9269 - val_f1_score: 0.9072
# Epoch 69/100
# 624/624 [==============================] - ETA: 0s - loss: 0.0089 - acc: 0.9377 - recall: 0.9914 - precision: 0.9922 - f1_score: 0.9438
# Epoch 00069: val_f1_score did not improve from 0.90717
# 624/624 [==============================] - 288s 462ms/step - loss: 0.0089 - acc: 0.9377 - recall: 0.9914 - precision: 0.9922 - f1_score: 0.9438 - val_loss: 0.1256 - val_acc: 0.9019 - val_recall: 0.9338 - val_precision: 0.9449 - val_f1_score: 0.9015
# Epoch 70/100
# 624/624 [==============================] - ETA: 0s - loss: 0.
100
# 624/624 [==============================] - ETA: 0s - loss: 0.0082 - acc: 0.9490 - recall: 0.9922 - precision: 0.9931 - f1_score: 0.9522
# Epoch 00077: val_f1_score did not improve from 0.90721
# 624/624 [==============================] - 284s 454ms/step - loss: 0.0082 - acc: 0.9490 - recall: 0.9922 - precision: 0.9931 - f1_score: 0.9522 - val_loss: 0.1202 - val_acc: 0.8947 - val_recall: 0.9361 - val_precision: 0.9423 - val_f1_score: 0.9020
# Epoch 78/100
# 624/624 [==============================] - ETA: 0s - loss: 0.0077 - acc: 0.9456 - recall: 0.9923 - precision: 0.9933 - f1_score: 0.9518
# Epoch 00078: val_f1_score improved from 0.90721 to 0.90742, saving model to /app/_data/models/final/Eff5HandComplex/Eff5HandComplex_5.h5
# 624/624 [==============================] - 289s 463ms/step - loss: 0.0077 - acc: 0.9456 - recall: 0.9923 - precision: 0.9933 - f1_score: 0.9518 - val_loss: 0.1226 - val_acc: 0.9075 - val_recall: 0.9328 - val_precision: 0.9450 - val_f1_score: 0.9074
# Epoch 79/100
# 624/624 [==============================] - ETA: 0s - loss: 0.0082 - acc: 0.9443 - recall: 0.9912 - precision: 0.9923 - f1_score: 0.9494
# Epoch 00079: val_f1_score did not improve from 0.90742
# 624/624 [==============================] - 287s 460ms/step - loss: 0.0082 - acc: 0.9443 - recall: 0.9912 - precision: 0.9923 - f1_score: 0.9494 - val_loss: 0.1269 - val_acc: 0.8947 - val_recall: 0.9256 - val_precision: 0.9472 - val_f1_score: 0.8928
# Epoch 80/100
# 624/624 [==============================] - ETA: 0s - loss: 0.0071 - acc: 0.9482 - recall: 0.9929 - precision: 0.9944 - f1_score: 0.9543
# Epoch 00080: val_f1_score improved from 0.90742 to 0.91158, saving model to /app/_data/models/final/Eff5HandComplex/Eff5HandComplex_5.h5
# 624/624 [==============================] - 286s 458ms/step - loss: 0.0071 - acc: 0.9482 - recall: 0.9929 - precision: 0.9944 - f1_score: 0.9543 - val_loss: 0.1331 - val_acc: 0.9066 - val_recall: 0.9326 - val_precision: 0.9427 - val_f1_score: 0.9116
# Epoch 81/100
# 624/624 [==============================] - ETA: 0s - loss: 0.0072 - acc: 0.9493 - recall: 0.9923 - precision: 0.9930 - f1_score: 0.9530
# Epoch 00081: val_f1_score did not improve from 0.91158
# 624/624 [==============================] - 283s 454ms/step - loss: 0.0072 - acc: 0.9493 - recall: 0.9923 - precision: 0.9930 - f1_score: 0.9530 - val_loss: 0.1250 - val_acc: 0.9051 - val_recall: 0.9400 - val_precision: 0.9319 - val_f1_score: 0.9062
# Epoch 82/100
# 624/624 [==============================] - ETA: 0s - loss: 0.0067 - acc: 0.9493 - recall: 0.9934 - precision: 0.9942 - f1_score: 0.9552
# Epoch 00082: val_f1_score did not improve from 0.91158
# 624/624 [==============================] - 283s 454ms/step - loss: 0.0067 - acc: 0.9493 - recall: 0.9934 - precision: 0.9942 - f1_score: 0.9552 - val_loss: 0.1321 - val_acc: 0.9034 - val_recall: 0.9361 - val_precision: 0.9401 - val_f1_score: 0.9055
# Epoch 83/100
# 624/624 [==============================] - ETA: 0s - loss: 0.0081 - acc: 0.9494 - recall: 0.9917 - precision: 0.9930 - f1_score: 0.9534
# Epoch 00083: val_f1_score did not improve from 0.91158
# 624/624 [==============================] - 284s 455ms/step - loss: 0.0081 - acc: 0.9494 - recall: 0.9917 - precision: 0.9930 - f1_score: 0.9534 - val_loss: 0.1260 - val_acc: 0.9038 - val_recall: 0.9313 - val_precision: 0.9385 - val_f1_score: 0.9020
# Epoch 84/100
# 624/624 [==============================] - ETA: 0s - loss: 0.0078 - acc: 0.9524 - recall: 0.9921 - precision: 0.9933 - f1_score: 0.9559
# Epoch 00084: val_f1_score did not improve from 0.91158
# 624/624 [==============================] - 287s 459ms/step - loss: 0.0078 - acc: 0.9524 - recall: 0.9921 - precision: 0.9933 - f1_score: 0.9559 - val_loss: 0.1405 - val_acc: 0.8903 - val_recall: 0.9231 - val_precision: 0.9376 - val_f1_score: 0.8937
# Epoch 85/100
# 624/624 [==============================] - ETA: 0s - loss: 0.0075 - acc: 0.9458 - recall: 0.9925 - precision: 0.9939 - f1_score: 0.9512
# Epoch 00085: val_f1_score did not improve from 0.91158
# 624/624 [==============================] - 284s 455ms/step - loss: 0.0075 - acc: 0.9458 - recall: 0.9925 - precision: 0.9939 - f1_score: 0.9512 - val_loss: 0.1296 - val_acc: 0.8987 - val_recall: 0.9334 - val_precision: 0.9445 - val_f1_score: 0.9014
# Epoch 86/100
# 624/624 [==============================] - ETA: 0s - loss: 0.0076 - acc: 0.9483 - recall: 0.9929 - precision: 0.9936 - f1_score: 0.9544
# Epoch 00086: val_f1_score did not improve from 0.91158
# 624/624 [==============================] - 285s 457ms/step - loss: 0.0076 - acc: 0.9483 - recall: 0.9929 - precision: 0.9936 - f1_score: 0.9544 - val_loss: 0.1293 - val_acc: 0.9075 - val_recall: 0.9357 - val_precision: 0.9368 - val_f1_score: 0.9107
# Epoch 87/100
# 624/624 [==============================] - ETA: 0s - loss: 0.0074 - acc: 0.9475 - recall: 0.9929 - precision: 0.9939 - f1_score: 0.9529
# Epoch 00087: val_f1_score did not improve from 0.91158
# 624/624 [==============================] - 285s 456ms/step - loss: 0.0074 - acc: 0.9475 - recall: 0.9929 - precision: 0.9939 - f1_score: 0.9529 - val_loss: 0.1261 - val_acc: 0.9026 - val_recall: 0.9319 - val_precision: 0.9393 - val_f1_score: 0.9041
# Epoch 88/100
# 624/624 [==============================] - ETA: 0s - loss: 0.0077 - acc: 0.9517 - recall: 0.9928 - precision: 0.9938 - f1_score: 0.9551
# Epoch 00088: val_f1_score did not improve from 0.91158
#
# Epoch 00088: ReduceLROnPlateau reducing learning rate to 0.0003645000251708552.
# 624/624 [==============================] - 282s 452ms/step - loss: 0.0077 - acc: 0.9517 - recall: 0.9928 - precision: 0.9938 - f1_score: 0.9551 - val_loss: 0.1267 - val_acc: 0.9006 - val_recall: 0.9400 - val_precision: 0.9400 - val_f1_score: 0.9053
# Epoch 89/100
# 624/624 [==============================] - ETA: 0s - loss: 0.0061 - acc: 0.9496 - recall: 0.9937 - precision: 0.9945 - f1_score: 0.9573
# Epoch 00089: val_f1_score did not improve from 0.91158
# 624/624 [==============================] - 285s 457ms/step - loss: 0.0061 - acc: 0.9496 - recall: 0.9937 - precision: 0.9945 - f1_score: 0.9573 - val_loss: 0.1239 - val_acc: 0.9063 - val_recall: 0.9394 - val_precision: 0.9442 - val_f1_score: 0.9097
# Epoch 90/100
# 624/624 [==============================] - ETA: 0s - loss: 0.0043 - acc: 0.9596 - recall: 0.9953 - precision: 0.9958 - f1_score: 0.9650
# Epoch 00090: val_f1_score did not improve from 0.91158
# 624/624 [==============================] - 283s 454ms/step - loss: 0.0043 - acc: 0.9596 - recall: 0.9953 - precision: 0.9958 - f1_score: 0.9650 - val_loss: 0.1300 - val_acc: 0.9083 - val_recall: 0.9385 - val_precision: 0.9422 - val_f1_score: 0.9098
# Epoch 91/100
# 624/624 [==============================] - ETA: 0s - loss: 0.0058 - acc: 0.9606 - recall: 0.9940 - precision: 0.9951 - f1_score: 0.9668
# Epoch 00091: val_f1_score did not improve from 0.91158
# 624/624 [==============================] - 283s 453ms/step - loss: 0.0058 - acc: 0.9606 - recall: 0.9940 - precision: 0.9951 - f1_score: 0.9668 - val_loss: 0.1409 - val_acc: 0.8950 - val_recall: 0.9235 - val_precision: 0.9481 - val_f1_score: 0.8997
# Epoch 92/100
# 624/624 [==============================] - ETA: 0s - loss: 0.0062 - acc: 0.9509 - recall: 0.9938 - precision: 0.9941 - f1_score: 0.9580Restoring model weights from the end of the best epoch.
#
# Epoch 00092: val_f1_score did not improve from 0.91158
# 624/624 [==============================] - 283s 454ms/step - loss: 0.0062 - acc: 0.9509 - recall: 0.9938 - precision: 0.9941 - f1_score: 0.9580 - val_loss: 0.1411 - val_acc: 0.8957 - val_recall: 0.9379 - val_precision: 0.9312 - val_f1_score: 0.9048
# Epoch 00092: early stopping

# %%
def parse_all(file_path):
    img = tf.io.read_file(TRAIN_IMG_PATH + file_path)
    img = tf.image.decode_jpeg(img, channels=3)
    return img


def predict_new(path, model):
    img = parse_all(path)
    img = tf.expand_dims(img, axis=0)
    pred = model.predict(img)
    return pred_to_labels(pred[0])

# %%
df_sub = pd.DataFrame(columns=["image", "labels"])
for img_name in os.listdir(TRAIN_IMG_PATH):
    pred = predict_new(img_name, model)

    df_sub = df_sub.append({"image": img_name, "labels": pred}, ignore_index=True)

print(df_sub.head())
# Out:
#                   image                   labels
# 0  bfc6d90f402f4c34.jpg  frog_eye_leaf_spot scab
# 1  9eb93fe282326266.jpg           powdery_mildew
# 2  f4cb3a8f41b413e4.jpg       frog_eye_leaf_spot
# 3  98322eab16bef2c1.jpg                     rust
# 4  dad5d6250cae80b7.jpg                  complex

# %%
df_sub = df_sub.merge(
    labels_21_20[["image", "labels"]],
    on="image",
    how="left",
    suffixes=("_pred", "_true"),
)

# %%
df_sub.to_csv("/app/sandbox/wrong_predictions/eff4/eff4_ns_cropped_2.csv")

# %%
df_sub[df_sub["labels_pred"] == ""]["labels_true"].value_counts()
# Out:
# complex                    22
# scab                       10
# rust                        7
# frog_eye_leaf_spot          5
# scab frog_eye_leaf_spot     1
# rust frog_eye_leaf_spot     1
# powdery_mildew complex      1
# powdery_mildew              1
# healthy                     1
# Name: labels_true, dtype: int64

# %%
df_sub[df_sub["labels_pred"] != df_sub["labels_true"]]["labels_true"].value_counts()
# Out:
# scab frog_eye_leaf_spot            682
# complex                            438
# scab frog_eye_leaf_spot complex    200
# frog_eye_leaf_spot complex         165
# scab                               124
# rust frog_eye_leaf_spot            118
# rust complex                        91
# powdery_mildew complex              87
# rust                                74
# frog_eye_leaf_spot                  71
# healthy                             19
# powdery_mildew                       7
# Name: labels_true, dtype: int64
